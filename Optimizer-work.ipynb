# %%
import pandas as pd
import numpy as np
import pickle
import json
import import_ipynb
import scipy
from scipy.optimize import minimize, fmin_powell, fmin, differential_evolution
import warnings
from my_libs.calc_features import *
from sklearn.preprocessing import StandardScaler
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 100
from scipy.optimize import minimize
# Out:
# importing Jupyter notebook from C:\Users\kseniya.yuldasheva\Desktop\gitPNTZtoyuk_1\gitPNTZ\PNTZ\my_libs\calc_features.ipynb

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
path = "DATA/Optimizer/input_3.xlsx"

# %%
targets = ['Предел текучести',
           'Врем. сопротивление']

dir_names = ['DATA/MODELS_RF/YS RF valid', 
             'DATA/MODELS_RF/H RF valid']

models_bonds = [
    'Текучесть середина',
    'Прочность середина'
]

# %%
ls_columns_output = [
    '№ партии',
    '№ плавки',
    'марка стали',
    'диаметр',
    'толщина стенки',
    'Гр. прочн.',
    '1 зона по ВТР закалка',
    '2 зона по ВТР закалка',
    '3 зона по ВТР закалка',
    'шаг балок закалочная печь, сек',
    'Скорость прохождения трубы через спрейер, м/с', 
    't˚ C трубы после спреера',
    '1 зона ВТР и уставка отпуск', 
    '2 зона ВТР и уставка отпуск', 
    '3 зона ВТР и уставка отпуск',
    '4 зона ВТР и уставка отпуск',
    '5 зона ВТР и уставка отпуск',
    'шаг балок отпускная печь, сек',
    'C',
    'Mn',
    'Si',
    'P',
    'S',
    'Cr',
    'Ni',
    'Cu',
    'Al',
    'V',
    'Ti',
    'Nb',
    'Mo',
    'N',
    'B',
    'C-coef',
    'Параметр закалка',
    'Параметр отпуск',
    'Параметр отпуск новый V',
    'Величина зерна',
    'Тип предела текучести (1186)',
    'Дата термообработки',
    'ICD',
    'Примечание',
#     'длина трубы'
    ]

# %%
table_for_optimize = pd.read_excel(path, skiprows=1)

# %% [markdown]
# ## Подготовка полученных от пользователя данных
#
# #### Что будет вводить пользователь?
#
# Обязательно:
# * группа прочности
# * марка стали
# * диаметр
# * толщина стенки
# * нижняя и верхняя границы допуска для предела текучести
# * нижняя и верхняя границы допуска для предела прочности
#
# Возможно:
# Режим термообработки, который нужно улучшить (он будет начальным приближением для алгоритма оптимизации):
#
# * 1 зона по ВТР закалка
# * 2 зона по ВТР закалка
# * 3 зона по ВТР закалка
# * Скорость прохождения трубы через спрейер, м/с
# * 1 зона ВТР и уставка отпуск
# * 2 зона ВТР и уставка отпуск
# * 3 зона ВТР и уставка отпуск
# * 4 зона ВТР и уставка отпуск
# * 5 зона ВТР и уставка отпуск
# * шаг балок закалочная печь, сек
# * шаг балок отпускная печь, сек
#
#
# Если режим термообработки не вводится, то будет подтягиваться исторический режим с минимальным шагом, в случае если шаг уже 24, режим оптимизироваться не будет (как в случае подтянутого исторического, так и в случае ручного ввода)
#
# Сформируем списки обязательных и необязательных входных данных

# %%
ls_opt_need = [
    'Гр. прочн.',
    'марка стали',
    'толщина стенки',
    'диаметр'
]

bounds = [
    'Предел текучести нижняя граница',
    'Предел текучести верхняя граница',
    'Предел прочности нижняя граница',
    'Предел прочности верхняя граница'
]

ls_additional = [
    '1 зона по ВТР закалка',
    '2 зона по ВТР закалка',
    '3 зона по ВТР закалка',
    'Скорость прохождения трубы через спрейер, м/с',
    '1 зона ВТР и уставка отпуск',
    '2 зона ВТР и уставка отпуск',
    '3 зона ВТР и уставка отпуск',
    '4 зона ВТР и уставка отпуск',
    '5 зона ВТР и уставка отпуск',
    'шаг балок закалочная печь, сек',
    'шаг балок отпускная печь, сек',
    'Тип предела текучести (1186)'
]

# %%
table_for_optimize
# Out:
#   Гр. прочн. марка стали  диаметр  толщина стенки  \
# 0          К       13ХФА     72.0             5.5
# 1          К        30Г2    118.0            12.0
# 2        R95      18ХМФБ     89.0             9.0
# 3        R95        Цу12     89.0             9.0
# 4          Л        30Г2    114.3             7.0
#
#    Предел текучести нижняя граница  Предел текучести верхняя граница  \
# 0                             40.0                               NaN
# 1                             50.0                               NaN
# 2                             66.8                              88.0
# 3                             77.3                               NaN
# 4                             66.8                              87.9
#
#    Предел прочности нижняя граница  Предел прочности верхняя граница  \
# 0                             60.0                               NaN
# 1                             70.0                               NaN
# 2                             70.0                              90.0
# 3                             70.0                              90.0
# 4                             77.3                               NaN
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                  840.0                  840.0                  840.0
# 3                  840.0                  840.0                  840.0
# 4                    NaN                    NaN                    NaN
#
#    Скорость прохождения трубы через спрейер, м/с  1 зона ВТР и уставка отпуск  \
# 0                                            NaN                          NaN
# 1                                            NaN                          NaN
# 2                                            0.2                        670.0
# 3                                            0.2                        670.0
# 4                                            NaN                          NaN
#
#    2 зона ВТР и уставка отпуск  3 зона ВТР и уставка отпуск  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                        670.0                        657.0
# 3                        670.0                        657.0
# 4                          NaN                          NaN
#
#    4 зона ВТР и уставка отпуск  5 зона ВТР и уставка отпуск  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                        657.0                        637.0
# 3                        657.0                        637.0
# 4                          NaN                          NaN
#
#    шаг балок закалочная печь, сек  шаг балок отпускная печь, сек  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                            28.0                           28.0
# 3                            28.0                           28.0
# 4                             NaN                            NaN
#
#    Тип предела текучести (1186)
# 0                           NaN
# 1                           NaN
# 2                           0.2
# 3                           0.2
# 4                           NaN

# %% [markdown]
# Если верхняя границп не введена, то берем нижнюю + 30

# %%
def fill_up(x):
    if pd.isnull(x['Предел текучести верхняя граница']):
        x['Предел текучести верхняя граница'] = x['Предел текучести нижняя граница']+30
    if pd.isnull(x['Предел прочности верхняя граница']):
        x['Предел прочности верхняя граница'] = x['Предел прочности нижняя граница']+30
    return x
table_for_optimize = table_for_optimize.apply(fill_up, axis=1)

# %%
table_for_optimize['Прочность середина'] = (table_for_optimize[
    'Предел прочности нижняя граница']+table_for_optimize['Предел прочности верхняя граница'])/2.0
table_for_optimize['Текучесть середина'] = (table_for_optimize[
    'Предел текучести нижняя граница']+table_for_optimize['Предел текучести верхняя граница'])/2.0

# %%
table_for_optimize
# Out:
#   Гр. прочн. марка стали  диаметр  толщина стенки  \
# 0          К       13ХФА     72.0             5.5
# 1          К        30Г2    118.0            12.0
# 2        R95      18ХМФБ     89.0             9.0
# 3        R95        Цу12     89.0             9.0
# 4          Л        30Г2    114.3             7.0
#
#    Предел текучести нижняя граница  Предел текучести верхняя граница  \
# 0                             40.0                              70.0
# 1                             50.0                              80.0
# 2                             66.8                              88.0
# 3                             77.3                             107.3
# 4                             66.8                              87.9
#
#    Предел прочности нижняя граница  Предел прочности верхняя граница  \
# 0                             60.0                              90.0
# 1                             70.0                             100.0
# 2                             70.0                              90.0
# 3                             70.0                              90.0
# 4                             77.3                             107.3
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                  840.0                  840.0                  840.0
# 3                  840.0                  840.0                  840.0
# 4                    NaN                    NaN                    NaN
#
#    Скорость прохождения трубы через спрейер, м/с  1 зона ВТР и уставка отпуск  \
# 0                                            NaN                          NaN
# 1                                            NaN                          NaN
# 2                                            0.2                        670.0
# 3                                            0.2                        670.0
# 4                                            NaN                          NaN
#
#    2 зона ВТР и уставка отпуск  3 зона ВТР и уставка отпуск  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                        670.0                        657.0
# 3                        670.0                        657.0
# 4                          NaN                          NaN
#
#    4 зона ВТР и уставка отпуск  5 зона ВТР и уставка отпуск  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                        657.0                        637.0
# 3                        657.0                        637.0
# 4                          NaN                          NaN
#
#    шаг балок закалочная печь, сек  шаг балок отпускная печь, сек  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                            28.0                           28.0
# 3                            28.0                           28.0
# 4                             NaN                            NaN
#
#    Тип предела текучести (1186)  Прочность середина  Текучесть середина
# 0                           NaN                75.0               55.00
# 1                           NaN                85.0               65.00
# 2                           0.2                80.0               77.40
# 3                           0.2                80.0               92.30
# 4                           NaN                92.3               77.35

# %% [markdown]
# ### Подтягиваем режим, если он не введен

# %%
database = pd.read_csv('prepared_to_saw_gp_del_bath.csv', index_col=0)

# %%
database.columns
# Out:
# Index(['№ партии', '№ плавки', 'марка стали', 'диаметр', 'толщина стенки',
#        'Гр. прочн.', '1 зона по ВТР закалка', '2 зона по ВТР закалка',
#        '3 зона по ВТР закалка', 'шаг балок закалочная печь, сек',
#        'Скорость прохождения трубы через спрейер, м/с',
#        't˚ C трубы после спреера', '1 зона ВТР и уставка отпуск',
#        '2 зона ВТР и уставка отпуск', '3 зона ВТР и уставка отпуск',
#        '4 зона ВТР и уставка отпуск', '5 зона ВТР и уставка отпуск',
#        'шаг балок отпускная печь, сек', 'C', 'Mn', 'Si', 'P', 'S', 'Cr', 'Ni',
#        'Cu', 'Al', 'V', 'Ti', 'Nb', 'Mo', 'N', 'B', 'C-coef',
#        'Параметр закалка', 'Параметр отпуск', 'Параметр отпуск новый V',
#        'Величина зерна', 'Тип предела текучести (1186)', 'Дата термообработки',
#        'ICD', 'Примечание', 'Предел текучести', 'Врем. сопротивление'],
#       dtype='object')

# %%
database = database[~(database['Скорость прохождения трубы через спрейер, м/с']==1)]
database = database[~(pd.isnull(database['Скорость прохождения трубы через спрейер, м/с']))]

# %% [markdown]
# #### Очищаем группу прочности, файл пересохранила, теперь это нужно для самого оптимизатора только

# %%
replace_dict_gr = {
    ' ':'',
    '/':'-',
    'ТИП':'тип',
    'К':'K', #русский на английский, везде
    'С':'C',
    'Р':'P',
    'Х':'X',
    'Е':'E',
    'Т':'T',
    'М':'M',
    'У':'Y',
    'Н':'H',
    'В':'B',
    'А':'A',
    'П':'n',
    'О':'O',
    'Т':'T'
}

def fix_h_group(st):
    st = str(st)
    st = st.upper()
    for it in replace_dict_gr:
        st = st.replace(it, replace_dict_gr[it])
    return st

# %%
# database.to_csv('prepared_to_saw_gp_del_bath.csv')

# %%
database['Гр. прочн.'] = database['Гр. прочн.'].apply(fix_h_group)
database['Примечание'] = database['Гр. прочн.'].apply(lambda x: None)

# database.to_csv('prepared_to_saw_gp_del_bath.csv')
# database

# %%
# database[ls_columns_output+targets].to_csv('prepared_to_saw_gp_del_bath.csv')

# %% [markdown]
# #### Ищем ближайший режим

# %%
def close_value(database, col, value):
    database['diff'] = np.abs(database[col]-value)
    return database.loc[(database['diff']).argmin(),:][col]

# %%
def find_row_close_sort(database, row):
    for col in ls_opt_need:
        tmp = database[database[col]==row[col]]
        if tmp.shape[0]>0:
            database = tmp
        else:
            try:
                value = close_value(database, col, row[col])
                database = database[database[col]==value]
            except TypeError:
                database = database[database[col]==row[col].split('-')[0]]
                if database.shape[0]==0:
                    tmp = row
                    tmp[[col for col in row.index if col not in ls_opt_need]] = None
                    tmp['№ партии'] = 'Error!!! (причина:'+ col+')'
                    return tmp
    row_new = pd.Series(database[database['Дата термообработки'] == database['Дата термообработки'].max()].iloc[0, :])
    row_new[ls_opt_need] = row[ls_opt_need].copy()
    return row_new

# %%
def find_close_sort(database, df):
    df['Гр. прочн.'] = df['Гр. прочн.'].apply(fix_h_group)
    df = df.apply(lambda x: find_row_close_sort(database, x), axis=1)
    return df

# %%
answ = find_close_sort(database, table_for_optimize)

# %%
answ
# Out:
#    1 зона ВТР и уставка отпуск  1 зона по ВТР закалка  \
# 0                        525.0                  840.0
# 1                        525.0                  850.0
# 2                        670.0                  870.0
# 3                          NaN                    NaN
# 4                        567.5                  850.0
#
#    2 зона ВТР и уставка отпуск  2 зона по ВТР закалка  \
# 0                        525.0                  840.0
# 1                        580.0                  850.0
# 2                        670.0                  870.0
# 3                          NaN                    NaN
# 4                        570.0                  850.0
#
#    3 зона ВТР и уставка отпуск  3 зона по ВТР закалка  \
# 0                     522.0000                  850.0
# 1                     522.0000                  860.0
# 2                     659.0000                  880.0
# 3                          NaN                    NaN
# 4                     561.1875                  860.0
#
#    4 зона ВТР и уставка отпуск  5 зона ВТР и уставка отпуск     Al        B  \
# 0                        522.0                        521.0  0.033  0.00094
# 1                        574.0                        521.0  0.030  0.00050
# 2                        659.0                        642.0  0.031      NaN
# 3                          NaN                          NaN    NaN      NaN
# 4                        564.0                        552.5  0.030  0.00050
#
#       C    C-coef    Cr    Cu       ICD    Mn     Mo        N       Nb    Ni  \
# 0  0.14  0.348000  0.53  0.10  0.579200  0.48  0.007  0.00800  0.00355  0.05
# 1  0.29  0.527267  0.06  0.08  1.198637  1.29  0.005  0.00892  0.00553  0.05
# 2  0.16  0.523333  1.02  0.19  1.682538  0.56  0.150  0.01000  0.04000  0.14
# 3   NaN       NaN   NaN   NaN       NaN   NaN    NaN      NaN      NaN   NaN
# 4  0.28  0.551267  0.09  0.19  1.450899  1.38  0.010  0.00800  0.00200  0.12
#
#        P      S    Si      Ti      V   diff  t˚ C трубы после спреера  \
# 0  0.007  0.003  0.24  0.0017  0.053  16.90                      37.5
# 1  0.012  0.008  0.23  0.0040  0.003  44.98                      42.5
# 2  0.010  0.007  0.23  0.0070  0.070  15.98                      70.0
# 3    NaN    NaN   NaN     NaN    NaN    NaN                       NaN
# 4  0.007  0.006  0.25  0.0100  0.003    NaN                      42.5
#
#    Величина зерна  Врем. сопротивление Гр. прочн. Дата термообработки  \
# 0       12.986261            62.500000          K          2014-12-13
# 1       17.473343            80.000000          K          2013-12-22
# 2        3.706300            86.760204        R95          2018-04-11
# 3             NaN                  NaN        R95                 NaN
# 4       13.518191            82.500000          Л          2016-11-12
#
#    Параметр закалка  Параметр отпуск  Параметр отпуск новый V  \
# 0        838.854999        15.844163                11.137841
# 1        847.359565        16.143345                10.032797
# 2        861.528411        18.202860                11.362842
# 3               NaN              NaN                      NaN
# 4        847.442750        16.509568                10.064960
#
#    Предел прочности верхняя граница  Предел прочности нижняя граница  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
#
#    Предел текучести  Предел текучести верхняя граница  \
# 0         47.000000                               NaN
# 1         59.000000                               NaN
# 2         81.632653                               NaN
# 3               NaN                               NaN
# 4         74.000000                               NaN
#
#    Предел текучести нижняя граница  Примечание  Прочность середина  \
# 0                              NaN         NaN                 NaN
# 1                              NaN         NaN                 NaN
# 2                              NaN         NaN                 NaN
# 3                              NaN         NaN                 NaN
# 4                              NaN         NaN                 NaN
#
#    Скорость прохождения трубы через спрейер, м/с  Текучесть середина  \
# 0                                       0.180000                 NaN
# 1                                       0.230000                 NaN
# 2                                       0.700000                 NaN
# 3                                            NaN                 NaN
# 4                                       0.386875                 NaN
#
#    Тип предела текучести (1186)  диаметр марка стали  толщина стенки  \
# 0                           0.2     72.0       13ХФА             5.5
# 1                           0.2    118.0        30Г2            12.0
# 2                           0.5     89.0      18ХМФБ             9.0
# 3                           NaN     89.0        Цу12             9.0
# 4                           0.2    114.3        30Г2             7.0
#
#    шаг балок закалочная печь, сек  шаг балок отпускная печь, сек  \
# 0                          36.000                        36.0000
# 1                          34.000                        34.0000
# 2                          27.000                        27.0000
# 3                             NaN                            NaN
# 4                          34.125                        32.5625
#
#                          № партии № плавки
# 0                          412197   z20302
# 1                          312280   v22228
# 2                          804140   8f1869
# 3  Error!!! (причина:марка стали)      NaN
# 4                          611199   6f3508

# %% [markdown]
# #### Оставляем введенные режимы
#
# Немного костыльно, если будет время нкужно будент поменять местами, сначала оставляем те, что уже введены, потом для оставшихся ищем режим.

# %%
try_ = table_for_optimize.copy()
try_ = try_.dropna()

# %%
try_
# Out:
#   Гр. прочн. марка стали  диаметр  толщина стенки  \
# 2        R95      18ХМФБ     89.0             9.0
# 3        R95        Цу12     89.0             9.0
#
#    Предел текучести нижняя граница  Предел текучести верхняя граница  \
# 2                             66.8                              88.0
# 3                             77.3                             107.3
#
#    Предел прочности нижняя граница  Предел прочности верхняя граница  \
# 2                             70.0                              90.0
# 3                             70.0                              90.0
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 2                  840.0                  840.0                  840.0
# 3                  840.0                  840.0                  840.0
#
#    Скорость прохождения трубы через спрейер, м/с  1 зона ВТР и уставка отпуск  \
# 2                                            0.2                        670.0
# 3                                            0.2                        670.0
#
#    2 зона ВТР и уставка отпуск  3 зона ВТР и уставка отпуск  \
# 2                        670.0                        657.0
# 3                        670.0                        657.0
#
#    4 зона ВТР и уставка отпуск  5 зона ВТР и уставка отпуск  \
# 2                        657.0                        637.0
# 3                        657.0                        637.0
#
#    шаг балок закалочная печь, сек  шаг балок отпускная печь, сек  \
# 2                            28.0                           28.0
# 3                            28.0                           28.0
#
#    Тип предела текучести (1186)  Прочность середина  Текучесть середина
# 2                           0.2                80.0                77.4
# 3                           0.2                80.0                92.3

# %%
def get_index_diff(df1,df2):
    return list(set(df1.index).difference(set(df2.index)))

# %%
diff = get_index_diff(answ, try_)

# %%
answ = pd.concat([answ.take(diff), try_])
answ = answ[ls_columns_output]

# %% [markdown]
# ## <span style="color:red">t˚ C трубы после спреера, если не пересчитывать все введенные вручную режимы обрубаются</span>

# %%
answ
# Out:
#   № партии № плавки марка стали  диаметр  толщина стенки Гр. прочн.  \
# 0   412197   z20302       13ХФА     72.0             5.5          K
# 1   312280   v22228        30Г2    118.0            12.0          K
# 4   611199   6f3508        30Г2    114.3             7.0          Л
# 2      NaN      NaN      18ХМФБ     89.0             9.0        R95
# 3      NaN      NaN        Цу12     89.0             9.0        R95
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  840.0                  840.0                  850.0
# 1                  850.0                  850.0                  860.0
# 4                  850.0                  850.0                  860.0
# 2                  840.0                  840.0                  840.0
# 3                  840.0                  840.0                  840.0
#
#    шаг балок закалочная печь, сек  \
# 0                          36.000
# 1                          34.000
# 4                          34.125
# 2                          28.000
# 3                          28.000
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 4                                       0.386875                      42.5
# 2                                       0.200000                       NaN
# 3                                       0.200000                       NaN
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        525.0                        525.0
# 1                        525.0                        580.0
# 4                        567.5                        570.0
# 2                        670.0                        670.0
# 3                        670.0                        670.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     522.0000                        522.0
# 1                     522.0000                        574.0
# 4                     561.1875                        564.0
# 2                     657.0000                        657.0
# 3                     657.0000                        657.0
#
#    5 зона ВТР и уставка отпуск  шаг балок отпускная печь, сек     C    Mn  \
# 0                        521.0                        36.0000  0.14  0.48
# 1                        521.0                        34.0000  0.29  1.29
# 4                        552.5                        32.5625  0.28  1.38
# 2                        637.0                        28.0000   NaN   NaN
# 3                        637.0                        28.0000   NaN   NaN
#
#      Si      P      S    Cr    Ni    Cu     Al      V      Ti       Nb     Mo  \
# 0  0.24  0.007  0.003  0.53  0.05  0.10  0.033  0.053  0.0017  0.00355  0.007
# 1  0.23  0.012  0.008  0.06  0.05  0.08  0.030  0.003  0.0040  0.00553  0.005
# 4  0.25  0.007  0.006  0.09  0.12  0.19  0.030  0.003  0.0100  0.00200  0.010
# 2   NaN    NaN    NaN   NaN   NaN   NaN    NaN    NaN     NaN      NaN    NaN
# 3   NaN    NaN    NaN   NaN   NaN   NaN    NaN    NaN     NaN      NaN    NaN
#
#          N        B    C-coef  Параметр закалка  Параметр отпуск  \
# 0  0.00800  0.00094  0.348000        838.854999        15.844163
# 1  0.00892  0.00050  0.527267        847.359565        16.143345
# 4  0.00800  0.00050  0.551267        847.442750        16.509568
# 2      NaN      NaN       NaN               NaN              NaN
# 3      NaN      NaN       NaN               NaN              NaN
#
#    Параметр отпуск новый V  Величина зерна  Тип предела текучести (1186)  \
# 0                11.137841       12.986261                           0.2
# 1                10.032797       17.473343                           0.2
# 4                10.064960       13.518191                           0.2
# 2                      NaN             NaN                           0.2
# 3                      NaN             NaN                           0.2
#
#   Дата термообработки       ICD  Примечание
# 0          2014-12-13  0.579200         NaN
# 1          2013-12-22  1.198637         NaN
# 4          2016-11-12  1.450899         NaN
# 2                 NaN       NaN         NaN
# 3                 NaN       NaN         NaN

# %%
table_for_optimize
# Out:
#   Гр. прочн. марка стали  диаметр  толщина стенки  \
# 0          K       13ХФА     72.0             5.5
# 1          K        30Г2    118.0            12.0
# 2        R95      18ХМФБ     89.0             9.0
# 3        R95        Цу12     89.0             9.0
# 4          Л        30Г2    114.3             7.0
#
#    Предел текучести нижняя граница  Предел текучести верхняя граница  \
# 0                             40.0                              70.0
# 1                             50.0                              80.0
# 2                             66.8                              88.0
# 3                             77.3                             107.3
# 4                             66.8                              87.9
#
#    Предел прочности нижняя граница  Предел прочности верхняя граница  \
# 0                             60.0                              90.0
# 1                             70.0                             100.0
# 2                             70.0                              90.0
# 3                             70.0                              90.0
# 4                             77.3                             107.3
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                  840.0                  840.0                  840.0
# 3                  840.0                  840.0                  840.0
# 4                    NaN                    NaN                    NaN
#
#    Скорость прохождения трубы через спрейер, м/с  1 зона ВТР и уставка отпуск  \
# 0                                            NaN                          NaN
# 1                                            NaN                          NaN
# 2                                            0.2                        670.0
# 3                                            0.2                        670.0
# 4                                            NaN                          NaN
#
#    2 зона ВТР и уставка отпуск  3 зона ВТР и уставка отпуск  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                        670.0                        657.0
# 3                        670.0                        657.0
# 4                          NaN                          NaN
#
#    4 зона ВТР и уставка отпуск  5 зона ВТР и уставка отпуск  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                        657.0                        637.0
# 3                        657.0                        637.0
# 4                          NaN                          NaN
#
#    шаг балок закалочная печь, сек  шаг балок отпускная печь, сек  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                            28.0                           28.0
# 3                            28.0                           28.0
# 4                             NaN                            NaN
#
#    Тип предела текучести (1186)  Прочность середина  Текучесть середина
# 0                           NaN                75.0               55.00
# 1                           NaN                85.0               65.00
# 2                           0.2                80.0               77.40
# 3                           0.2                80.0               92.30
# 4                           NaN                92.3               77.35

# %%
answ = pd.concat([answ,table_for_optimize[['Прочность середина', 'Текучесть середина']]], axis=1)

# %%
answ
# Out:
#   № партии № плавки марка стали  диаметр  толщина стенки Гр. прочн.  \
# 0   412197   z20302       13ХФА     72.0             5.5          K
# 1   312280   v22228        30Г2    118.0            12.0          K
# 2      NaN      NaN      18ХМФБ     89.0             9.0        R95
# 3      NaN      NaN        Цу12     89.0             9.0        R95
# 4   611199   6f3508        30Г2    114.3             7.0          Л
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  840.0                  840.0                  850.0
# 1                  850.0                  850.0                  860.0
# 2                  840.0                  840.0                  840.0
# 3                  840.0                  840.0                  840.0
# 4                  850.0                  850.0                  860.0
#
#    шаг балок закалочная печь, сек  \
# 0                          36.000
# 1                          34.000
# 2                          28.000
# 3                          28.000
# 4                          34.125
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 2                                       0.200000                       NaN
# 3                                       0.200000                       NaN
# 4                                       0.386875                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        525.0                        525.0
# 1                        525.0                        580.0
# 2                        670.0                        670.0
# 3                        670.0                        670.0
# 4                        567.5                        570.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     522.0000                        522.0
# 1                     522.0000                        574.0
# 2                     657.0000                        657.0
# 3                     657.0000                        657.0
# 4                     561.1875                        564.0
#
#    5 зона ВТР и уставка отпуск  шаг балок отпускная печь, сек     C    Mn  \
# 0                        521.0                        36.0000  0.14  0.48
# 1                        521.0                        34.0000  0.29  1.29
# 2                        637.0                        28.0000   NaN   NaN
# 3                        637.0                        28.0000   NaN   NaN
# 4                        552.5                        32.5625  0.28  1.38
#
#      Si      P      S    Cr    Ni    Cu     Al      V      Ti       Nb     Mo  \
# 0  0.24  0.007  0.003  0.53  0.05  0.10  0.033  0.053  0.0017  0.00355  0.007
# 1  0.23  0.012  0.008  0.06  0.05  0.08  0.030  0.003  0.0040  0.00553  0.005
# 2   NaN    NaN    NaN   NaN   NaN   NaN    NaN    NaN     NaN      NaN    NaN
# 3   NaN    NaN    NaN   NaN   NaN   NaN    NaN    NaN     NaN      NaN    NaN
# 4  0.25  0.007  0.006  0.09  0.12  0.19  0.030  0.003  0.0100  0.00200  0.010
#
#          N        B    C-coef  Параметр закалка  Параметр отпуск  \
# 0  0.00800  0.00094  0.348000        838.854999        15.844163
# 1  0.00892  0.00050  0.527267        847.359565        16.143345
# 2      NaN      NaN       NaN               NaN              NaN
# 3      NaN      NaN       NaN               NaN              NaN
# 4  0.00800  0.00050  0.551267        847.442750        16.509568
#
#    Параметр отпуск новый V  Величина зерна  Тип предела текучести (1186)  \
# 0                11.137841       12.986261                           0.2
# 1                10.032797       17.473343                           0.2
# 2                      NaN             NaN                           0.2
# 3                      NaN             NaN                           0.2
# 4                10.064960       13.518191                           0.2
#
#   Дата термообработки       ICD  Примечание  Прочность середина  \
# 0          2014-12-13  0.579200         NaN                75.0
# 1          2013-12-22  1.198637         NaN                85.0
# 2                 NaN       NaN         NaN                80.0
# 3                 NaN       NaN         NaN                80.0
# 4          2016-11-12  1.450899         NaN                92.3
#
#    Текучесть середина
# 0               55.00
# 1               65.00
# 2               77.40
# 3               92.30
# 4               77.35

# %% [markdown]
# ###  Подтягиваем среднюю химию

# %%
answ = mean_chem(answ)

# %% [markdown]
# Убираем строчки без химии после подтягивания

# %%
answ = answ[~answ['C'].isnull()]
answ[ls_chem] = answ[ls_chem].fillna(0)

# %%
answ = calc_all_features(answ)
answ = len_pipe(answ)
answ = calc_AC(answ)

# %%
answ.reset_index(inplace=True, drop=True)
answ
# Out:
#   № партии № плавки марка стали  диаметр  толщина стенки Гр. прочн.  \
# 0   412197   z20302       13ХФА     72.0             5.5          K
# 1   312280   v22228        30Г2    118.0            12.0          K
# 2      NaN      NaN      18ХМФБ     89.0             9.0        R95
# 3   611199   6f3508        30Г2    114.3             7.0          Л
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  840.0                  840.0                  850.0
# 1                  850.0                  850.0                  860.0
# 2                  840.0                  840.0                  840.0
# 3                  850.0                  850.0                  860.0
#
#    шаг балок закалочная печь, сек  \
# 0                          36.000
# 1                          34.000
# 2                          28.000
# 3                          34.125
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 2                                       0.200000                       NaN
# 3                                       0.386875                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        525.0                        525.0
# 1                        525.0                        580.0
# 2                        670.0                        670.0
# 3                        567.5                        570.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     522.0000                        522.0
# 1                     522.0000                        574.0
# 2                     657.0000                        657.0
# 3                     561.1875                        564.0
#
#    5 зона ВТР и уставка отпуск  шаг балок отпускная печь, сек        C  \
# 0                        521.0                        36.0000  0.14000
# 1                        521.0                        34.0000  0.29000
# 2                        637.0                        28.0000  0.17656
# 3                        552.5                        32.5625  0.28000
#
#         Mn       Si        P        S       Cr       Ni      Cu       Al  \
# 0  0.48000  0.24000  0.00700  0.00300  0.53000  0.05000  0.1000  0.03300
# 1  1.29000  0.23000  0.01200  0.00800  0.06000  0.05000  0.0800  0.03000
# 2  0.57057  0.27012  0.00848  0.00582  0.99551  0.12524  0.1733  0.03268
# 3  1.38000  0.25000  0.00700  0.00600  0.09000  0.12000  0.1900  0.03000
#
#          V       Ti       Nb       Mo        N        B    C-coef  \
# 0  0.05300  0.00170  0.00355  0.00700  0.00800  0.00094  0.348000
# 1  0.00300  0.00400  0.00553  0.00500  0.00892  0.00050  0.527267
# 2  0.07311  0.01323  0.04006  0.14019  0.00834  0.00000  0.533320
# 3  0.00300  0.01000  0.00200  0.01000  0.00800  0.00050  0.551267
#
#    Параметр закалка  Параметр отпуск  Параметр отпуск новый V  Величина зерна  \
# 0        838.854999        15.844163                11.137841       12.986261
# 1        847.359565        16.143345                10.032797       17.473343
# 2        823.567356        18.177488                11.176230        2.502955
# 3        847.442750        16.509568                10.064960       13.518191
#
#    Тип предела текучести (1186) Дата термообработки       ICD  Примечание  \
# 0                           0.2          2014-12-13  0.579200         NaN
# 1                           0.2          2013-12-22  1.198637         NaN
# 2                           0.2                 NaN  1.843581         NaN
# 3                           0.2          2016-11-12  1.450899         NaN
#
#    Прочность середина  Текучесть середина  Параметр отпуск новый  \
# 0                75.0               55.00              49.920500
# 1                85.0               65.00              49.860488
# 2                80.0               77.40              49.666391
# 3                92.3               77.35              49.816823
#
#    Параметр отпуск новый 2      T  sum_piXi     sum_qiXi  длина трубы  W  \
# 0                11.618726  845.0 -2.927149 -24968.70310     5.040000  0
# 1                10.418611  855.0 -3.038328 -27300.77346    13.800000  0
# 2                11.783254  840.0  1.471933  30276.15789     4.000000  0
# 3                10.460386  855.0 -4.258518 -36421.41100    10.107109  0
#
#      AC3    AC1
# 0  865.5  733.0
# 1  810.0  714.5
# 2  858.5  745.0
# 3  808.5  714.0

# %%
# answ = pd.DataFrame(answ.iloc[3,:]).T

# %% [markdown]
# ### Загрузка моделей для предсказания свойств

# %%
def load_model(dir_name, target):
    model = pickle.load(open(dir_name+'/RF_model_'+target+'.sav', 'rb'))
    ls_need_col = json.load(open(dir_name+'/ls_need_col', "r"))
    try:
        scaler = StandardScaler()
        scale_data = json.load(open(dir_name+'/scaler', "r"))
        scaler.mean_ = scale_data[0]
        scaler.scale_ = scale_data[1]
    except:
        scaler=None
    return model, ls_need_col, scaler

# %%
models, ls_need_cols, scalers = [], [], []
for target, dir_name in zip(targets, dir_names):
    model, ls_need_col, scaler = load_model(dir_name, target)
    models.append(model)
    ls_need_cols.append(ls_need_col)
    scalers.append(scaler)

# %% [markdown]
# ### Подготовка шагов для оптимизатора

# %% [markdown]
# Возникла проблема, оптимизатор не работает с двумя моделями, потому что они обучены на разном подмножестве признаков, сейчас пробую обойти это, если не получится, то нужно будет переобучить модельки.
#
# Придумала костыль, живем дальше

# %%
ls_temp_z = [
    '1 зона по ВТР закалка', '2 зона по ВТР закалка',
    '3 зона по ВТР закалка'
]

ls_temp_o = [
    '1 зона ВТР и уставка отпуск',
    '2 зона ВТР и уставка отпуск', '3 зона ВТР и уставка отпуск',
    '4 зона ВТР и уставка отпуск', '5 зона ВТР и уставка отпуск'
]

# ls_s_spr = ['Скорость прохождения трубы через спрейер, м/с']

ls_shag = [
    'шаг балок закалочная печь, сек', 'шаг балок отпускная печь, сек'
]

ls_fit_param = ls_temp_o+ls_temp_z+ls_shag

# %%
answ.columns
# Out:
# Index(['№ партии', '№ плавки', 'марка стали', 'диаметр', 'толщина стенки',
#        'Гр. прочн.', '1 зона по ВТР закалка', '2 зона по ВТР закалка',
#        '3 зона по ВТР закалка', 'шаг балок закалочная печь, сек',
#        'Скорость прохождения трубы через спрейер, м/с',
#        't˚ C трубы после спреера', '1 зона ВТР и уставка отпуск',
#        '2 зона ВТР и уставка отпуск', '3 зона ВТР и уставка отпуск',
#        '4 зона ВТР и уставка отпуск', '5 зона ВТР и уставка отпуск',
#        'шаг балок отпускная печь, сек', 'C', 'Mn', 'Si', 'P', 'S', 'Cr', 'Ni',
#        'Cu', 'Al', 'V', 'Ti', 'Nb', 'Mo', 'N', 'B', 'C-coef',
#        'Параметр закалка', 'Параметр отпуск', 'Параметр отпуск новый V',
#        'Величина зерна', 'Тип предела текучести (1186)', 'Дата термообработки',
#        'ICD', 'Примечание', 'Прочность середина', 'Текучесть середина',
#        'Параметр отпуск новый', 'Параметр отпуск новый 2', 'T', 'sum_piXi',
#        'sum_qiXi', 'длина трубы', 'W', 'AC3', 'AC1'],
#       dtype='object')

# %%
def uniq(alist):    # Fastest order preserving
    set = {}
    return [set.setdefault(e,e) for e in alist if e not in set]

ls_need_union = uniq(list(sum(ls_need_cols, [])))

# %%
answ[ls_need_union + ['AC3', 'AC1']]
# Out:
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  840.0                  840.0                  850.0
# 1                  850.0                  850.0                  860.0
# 2                  840.0                  840.0                  840.0
# 3                  850.0                  850.0                  860.0
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 2                                       0.200000                       NaN
# 3                                       0.386875                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        525.0                        525.0
# 1                        525.0                        580.0
# 2                        670.0                        670.0
# 3                        567.5                        570.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     522.0000                        522.0
# 1                     522.0000                        574.0
# 2                     657.0000                        657.0
# 3                     561.1875                        564.0
#
#    5 зона ВТР и уставка отпуск  шаг балок закалочная печь, сек  \
# 0                        521.0                          36.000
# 1                        521.0                          34.000
# 2                        637.0                          28.000
# 3                        552.5                          34.125
#
#    шаг балок отпускная печь, сек  диаметр  толщина стенки        C       Mn  \
# 0                        36.0000     72.0             5.5  0.14000  0.48000
# 1                        34.0000    118.0            12.0  0.29000  1.29000
# 2                        28.0000     89.0             9.0  0.17656  0.57057
# 3                        32.5625    114.3             7.0  0.28000  1.38000
#
#         Si        P        S       Cr       Ni      Cu       Al        V  \
# 0  0.24000  0.00700  0.00300  0.53000  0.05000  0.1000  0.03300  0.05300
# 1  0.23000  0.01200  0.00800  0.06000  0.05000  0.0800  0.03000  0.00300
# 2  0.27012  0.00848  0.00582  0.99551  0.12524  0.1733  0.03268  0.07311
# 3  0.25000  0.00700  0.00600  0.09000  0.12000  0.1900  0.03000  0.00300
#
#         Ti       Nb       Mo        N  Параметр закалка  \
# 0  0.00170  0.00355  0.00700  0.00800        838.854999
# 1  0.00400  0.00553  0.00500  0.00892        847.359565
# 2  0.01323  0.04006  0.14019  0.00834        823.567356
# 3  0.01000  0.00200  0.01000  0.00800        847.442750
#
#    Параметр отпуск новый V    C-coef  Величина зерна  Параметр отпуск    AC3  \
# 0                11.137841  0.348000       12.986261        15.844163  865.5
# 1                10.032797  0.527267       17.473343        16.143345  810.0
# 2                11.176230  0.533320        2.502955        18.177488  858.5
# 3                10.064960  0.551267       13.518191        16.509568  808.5
#
#      AC1
# 0  733.0
# 1  714.5
# 2  745.0
# 3  714.0

# %%
X_c_down = calc_all_features(answ[ls_need_union + ['AC3', 'AC1']]).dropna().copy()

for col in ls_temp_z:
    X_c_down[col] = X_c_down.apply(lambda x: max(x['AC3'], x[col]-50), axis=1)

for el in ls_temp_o:
    X_c_down[el] = X_c_down.apply(lambda x: max(450, x[el]-50), axis=1)
    
for el in ls_shag:    
    X_c_down[el] = X_c_down.apply(lambda x: max(24, x[el]-8), axis=1)

# X_c_down['Скорость прохождения трубы через спрейер, м/с'] = X_c_down[
#     'Скорость прохождения трубы через спрейер, м/с'].apply(lambda x: x if x>0 else 0)

X_c_up = calc_all_features(answ[ls_need_union + ['AC3', 'AC1']]).dropna().copy()

for el in ls_temp_z: 
    X_c_up[el] = X_c_up.apply(lambda x: min(990, x[el]+50), axis=1)

for col in ls_temp_o:
    X_c_up[col] = X_c_up.apply(lambda x: min(x['AC1'], x[col]-50), axis=1)

# %%
X_c_down
# Out:
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  865.5                  865.5                  865.5
# 1                  810.0                  810.0                  810.0
# 3                  808.5                  808.5                  810.0
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 3                                       0.386875                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        475.0                        475.0
# 1                        475.0                        530.0
# 3                        517.5                        520.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     472.0000                        472.0
# 1                     472.0000                        524.0
# 3                     511.1875                        514.0
#
#    5 зона ВТР и уставка отпуск  шаг балок закалочная печь, сек  \
# 0                        471.0                          28.000
# 1                        471.0                          26.000
# 3                        502.5                          26.125
#
#    шаг балок отпускная печь, сек  диаметр  толщина стенки     C    Mn    Si  \
# 0                        28.0000     72.0             5.5  0.14  0.48  0.24
# 1                        26.0000    118.0            12.0  0.29  1.29  0.23
# 3                        24.5625    114.3             7.0  0.28  1.38  0.25
#
#        P      S    Cr    Ni    Cu     Al      V      Ti       Nb     Mo  \
# 0  0.007  0.003  0.53  0.05  0.10  0.033  0.053  0.0017  0.00355  0.007
# 1  0.012  0.008  0.06  0.05  0.08  0.030  0.003  0.0040  0.00553  0.005
# 3  0.007  0.006  0.09  0.12  0.19  0.030  0.003  0.0100  0.00200  0.010
#
#          N  Параметр закалка  Параметр отпуск новый V    C-coef  \
# 0  0.00800        838.854999                11.137841  0.348000
# 1  0.00892        847.359565                10.032797  0.527267
# 3  0.00800        847.442750                10.064960  0.551267
#
#    Величина зерна  Параметр отпуск    AC3    AC1       ICD  \
# 0       12.986261        15.844163  865.5  733.0  0.579200
# 1       17.473343        16.143345  810.0  714.5  1.198637
# 3       13.518191        16.509568  808.5  714.0  1.450899
#
#    Параметр отпуск новый  Параметр отпуск новый 2      T  sum_piXi  \
# 0              49.920500                11.618726  845.0 -2.927149
# 1              49.860488                10.418611  855.0 -3.038328
# 3              49.816823                10.460386  855.0 -4.258518
#
#       sum_qiXi
# 0 -24968.70310
# 1 -27300.77346
# 3 -36421.41100

# %%
X_c_up
# Out:
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  890.0                  890.0                  900.0
# 1                  900.0                  900.0                  910.0
# 3                  900.0                  900.0                  910.0
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 3                                       0.386875                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        475.0                        475.0
# 1                        475.0                        530.0
# 3                        517.5                        520.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     472.0000                        472.0
# 1                     472.0000                        524.0
# 3                     511.1875                        514.0
#
#    5 зона ВТР и уставка отпуск  шаг балок закалочная печь, сек  \
# 0                        471.0                          36.000
# 1                        471.0                          34.000
# 3                        502.5                          34.125
#
#    шаг балок отпускная печь, сек  диаметр  толщина стенки     C    Mn    Si  \
# 0                        36.0000     72.0             5.5  0.14  0.48  0.24
# 1                        34.0000    118.0            12.0  0.29  1.29  0.23
# 3                        32.5625    114.3             7.0  0.28  1.38  0.25
#
#        P      S    Cr    Ni    Cu     Al      V      Ti       Nb     Mo  \
# 0  0.007  0.003  0.53  0.05  0.10  0.033  0.053  0.0017  0.00355  0.007
# 1  0.012  0.008  0.06  0.05  0.08  0.030  0.003  0.0040  0.00553  0.005
# 3  0.007  0.006  0.09  0.12  0.19  0.030  0.003  0.0100  0.00200  0.010
#
#          N  Параметр закалка  Параметр отпуск новый V    C-coef  \
# 0  0.00800        838.854999                11.137841  0.348000
# 1  0.00892        847.359565                10.032797  0.527267
# 3  0.00800        847.442750                10.064960  0.551267
#
#    Величина зерна  Параметр отпуск    AC3    AC1       ICD  \
# 0       12.986261        15.844163  865.5  733.0  0.579200
# 1       17.473343        16.143345  810.0  714.5  1.198637
# 3       13.518191        16.509568  808.5  714.0  1.450899
#
#    Параметр отпуск новый  Параметр отпуск новый 2      T  sum_piXi  \
# 0              49.920500                11.618726  845.0 -2.927149
# 1              49.860488                10.418611  855.0 -3.038328
# 3              49.816823                10.460386  855.0 -4.258518
#
#       sum_qiXi
# 0 -24968.70310
# 1 -27300.77346
# 3 -36421.41100

# %%
# X_c_up = X_c_up[ls_need_union].dropna()
# X_c_down = X_c_down[ls_need_union].dropna()

# %% [markdown]
# Добавлю еще один костыль в виде самостоятельной првоерки по границам.....

# %%
def is_in_bounds(row, bounds):
    penalty = 0
    for i in range(len(bounds)):
        if bounds[i][0]<=row.iloc[:, i].values<=bounds[i][1]:
            pass
        else:
            penalty += 100
    return penalty

# %%
# Это нужно?
# df = pd.DataFrame(df, index=ls_need_union).T

# %%
# tmp_try_headers = answ_n[ls_fit_param].iloc[0,:].values
# pd.DataFrame(tmp_try_headers, index=ls_fit_param).T
# tmp_try_headers.shape
# ls_fit_param

# %%
def model_pr(fit_params, all_params, bounds, eta):
    centr_ys = all_params['Текучесть середина']
    centr_h = all_params['Прочность середина']
    all_params = pd.concat([all_params[list(set(ls_need_union + ['длина трубы'])-set(ls_fit_param))],
                            pd.Series(fit_params, index=ls_fit_param)])
    fit_params = pd.DataFrame(fit_params, index=ls_fit_param).T
    score = 0
    
# пересчет параметров
    if pd.DataFrame(all_params).shape[0] > pd.DataFrame(all_params).shape[1]:
        all_params = pd.DataFrame(all_params).T
    else:
        all_params = pd.DataFrame(all_params)
    all_params = calc_all_features(all_params)
    all_params = new_spr(all_params)
# попытки победить ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
    all_params.reset_index(inplace=True, drop=True)
    all_params.dropna(inplace=True)
    all_params = all_params.astype(np.float32)
    for model_name, model, ls_need_col, scaler in zip(['ys','h'], models, ls_need_cols, scalers):
        if model_name=='h':
            centr=centr_h
            pred = model.predict(all_params[ls_need_col])
            tmp_score = np.abs(pred - centr)
        else:
            centr=centr_ys
            pred = model.predict(all_params[ls_need_col])
            tmp_score = np.abs(pred - centr)
        if tmp_score<2:
            tmp_score=0
        if tmp_score > 5:
#             tmp_score+=float('inf')
            tmp_score += 100
        
        score += tmp_score
    
    
    score += max(np.abs(all_params['шаг балок закалочная печь, сек'].values-24),
                 np.abs(all_params['шаг балок отпускная печь, сек'].values-24))*eta
    score += is_in_bounds(fit_params, bounds)
    return score

# %%
answ_n = answ[ls_need_union + models_bonds + ['длина трубы']].dropna()

# %%
answ_n = answ[ls_columns_output + models_bonds + ['длина трубы']].dropna()

# %%
from scipy.optimize import brute, basinhopping

# %%
ls_answ_n = ls_columns_output + models_bonds + ['длина трубы']
ls_answ_n.remove('Примечание')
answ_n = answ[ls_answ_n]
answ_n = answ_n.dropna()
answ_n
# Out:
#   № партии № плавки марка стали  диаметр  толщина стенки Гр. прочн.  \
# 0   412197   z20302       13ХФА     72.0             5.5          K
# 1   312280   v22228        30Г2    118.0            12.0          K
# 3   611199   6f3508        30Г2    114.3             7.0          Л
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0                  840.0                  840.0                  850.0
# 1                  850.0                  850.0                  860.0
# 3                  850.0                  850.0                  860.0
#
#    шаг балок закалочная печь, сек  \
# 0                          36.000
# 1                          34.000
# 3                          34.125
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.180000                      37.5
# 1                                       0.230000                      42.5
# 3                                       0.386875                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                        525.0                        525.0
# 1                        525.0                        580.0
# 3                        567.5                        570.0
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                     522.0000                        522.0
# 1                     522.0000                        574.0
# 3                     561.1875                        564.0
#
#    5 зона ВТР и уставка отпуск  шаг балок отпускная печь, сек     C    Mn  \
# 0                        521.0                        36.0000  0.14  0.48
# 1                        521.0                        34.0000  0.29  1.29
# 3                        552.5                        32.5625  0.28  1.38
#
#      Si      P      S    Cr    Ni    Cu     Al      V      Ti       Nb     Mo  \
# 0  0.24  0.007  0.003  0.53  0.05  0.10  0.033  0.053  0.0017  0.00355  0.007
# 1  0.23  0.012  0.008  0.06  0.05  0.08  0.030  0.003  0.0040  0.00553  0.005
# 3  0.25  0.007  0.006  0.09  0.12  0.19  0.030  0.003  0.0100  0.00200  0.010
#
#          N        B    C-coef  Параметр закалка  Параметр отпуск  \
# 0  0.00800  0.00094  0.348000        838.854999        15.844163
# 1  0.00892  0.00050  0.527267        847.359565        16.143345
# 3  0.00800  0.00050  0.551267        847.442750        16.509568
#
#    Параметр отпуск новый V  Величина зерна  Тип предела текучести (1186)  \
# 0                11.137841       12.986261                           0.2
# 1                10.032797       17.473343                           0.2
# 3                10.064960       13.518191                           0.2
#
#   Дата термообработки       ICD  Текучесть середина  Прочность середина  \
# 0          2014-12-13  0.579200               55.00                75.0
# 1          2013-12-22  1.198637               65.00                85.0
# 3          2016-11-12  1.450899               77.35                92.3
#
#    длина трубы
# 0     5.040000
# 1    13.800000
# 3    10.107109

# %%
# %%time
answers_array = []
# tmp_res = []
X_a = calc_all_features(X_c_down[ls_need_union]).copy()
X_b = calc_all_features(X_c_up[ls_need_union]).copy()
answ_n.reset_index(inplace=True, drop=True)
X_a.reset_index(inplace=True, drop=True)
X_b.reset_index(inplace=True, drop=True)
answ_n.reset_index(inplace=True, drop=True)
for it in X_a.index:
    bounds = [(i, j) for i, j in zip(X_a.loc[it,ls_fit_param], X_b.loc[it,ls_fit_param])]
    print(answ_n.iloc[it,-3],answ_n.iloc[it,-2])
    all_params = answ_n.iloc[it,:]
    fit_p = answ_n.loc[it, ls_fit_param]
    
#     a = minimize(lambda fit_params: model_pr(fit_params, 
#                                              all_params,
#                                              bounds, 
#                                              10),
#                  fit_p, method='TNC', bounds=bounds)


    a = fmin(lambda fit_params: model_pr(fit_params, 
                                             all_params,
                                             bounds, 
                                             10),
                 fit_p)


#     a = differential_evolution(lambda fit_params: model_pr(fit_params,all_params,bounds,10), bounds)


#     a = basinhopping(lambda fit_params: model_pr(fit_params,all_params,bounds,10), fit_p)
    
    print('ВАПРОС a', it, models[0].predict(X_a.loc[it,ls_need_cols[0]].values.reshape(1, -1)),
         models[1].predict(X_a.loc[it,ls_need_cols[1]].values.reshape(1, -1)))
    print('ВАПРОС origin', it, models[0].predict(answ_n.loc[it,ls_need_cols[0]].values.reshape(1, -1)),
         models[1].predict(answ_n.loc[it,ls_need_cols[1]].values.reshape(1, -1)))
    print('ВАПРОС b', it, models[0].predict(X_b.loc[it,ls_need_cols[0]].values.reshape(1, -1)),
         models[1].predict(X_b.loc[it,ls_need_cols[1]].values.reshape(1, -1)))
    print(a)
    print('1')
#     tmp_res.append(all_params)
    all_params = pd.concat([all_params[set(ls_columns_output+['длина трубы','Текучесть середина', 'Прочность середина'])-set(ls_fit_param)],pd.Series(a, index=ls_fit_param)])
    print('2')
    answers_array.append(all_params)
#     tmp_a_x = a['x']
#     df_h = np.concatenate((tmp_a_x[:2],tmp_a_x[3:-2],tmp_a_x[-1:]))
#     df_ys = tmp_a_x[:-1]
    ys = models[0].predict(calc_all_features(pd.DataFrame(answers_array[-1]).T)[ls_need_cols[0]])
    h = models[1].predict(calc_all_features(pd.DataFrame(answers_array[-1]).T)[ls_need_cols[1]])
    answers_array[-1] = pd.concat([answers_array[-1], pd.Series([ys[0],h[0]], index=['pred Текучесть', 'pred Прочность'])])
    print('АТВЕТ ', it, ys, h)
# Out:
# 55.0 75.0
# Optimization terminated successfully.
#          Current function value: 654.700309
#          Iterations: 350
#          Function evaluations: 724
# ВАПРОС a 0 [54.26193199] [69.07735714]
# ВАПРОС origin 0 [49.9525581] [66.43810544]
# ВАПРОС b 0 [52.44418711] [68.05911565]
# [566.67157002 606.75459157 558.1109609  610.81366179 469.46395678
#  877.80563067 870.35960888 898.80124796  28.00000042  28.00000455]
# 1
# 2
# АТВЕТ  0 [50.55934456] [65.18311224]
# 65.0 85.0
# Optimization terminated successfully.
#          Current function value: 523.506053
#          Iterations: 394
#          Function evaluations: 764
# ВАПРОС a 1 [78.12536255] [93.68698479]
# ВАПРОС origin 1 [69.21999756] [83.86840737]
# ВАПРОС b 1 [77.10301724] [91.46936575]
# [525.82342619 739.64990879 480.95181096 954.40957665 248.13452619
#  890.60551435 879.24447824 875.99053823  26.00000094  26.00000021]
# 1
# 2
# АТВЕТ  1 [65.78250726] [81.45279013]
# 77.35 92.3
# Optimization terminated successfully.
#          Current function value: 521.250000
#          Iterations: 271
#          Function evaluations: 628
# ВАПРОС a 2 [79.75280453] [92.78996894]
# ВАПРОС origin 2 [74.90503835] [83.710186]
# ВАПРОС b 2 [79.36217223] [92.14550747]
# [631.65874914 609.26469936 591.95323788 460.70929888 635.94641272
#  867.25683769 879.15389771 902.58547731  26.12500004  26.01703228]
# 1
# 2
# АТВЕТ  2 [75.95224541] [91.76778116]
# Wall time: 2min 27s

# %%
opt_answer_end = pd.DataFrame(answers_array)
opt_answer_end = calc_all_features(opt_answer_end)
opt_answer_end = new_spr(opt_answer_end)
# opt_answer_end = opt_answer_end[ls_need_cols[0]+['pred Текучесть','pred Прочность']].copy()
output_df = opt_answer_end[ls_answ_n+['pred Текучесть','pred Прочность']].copy()
output_df
# Out:
#    № партии № плавки марка стали  диаметр  толщина стенки Гр. прочн.  \
# 0    412197   z20302       13ХФА     72.0             5.5          K
# 1    312280   v22228        30Г2    118.0            12.0          K
# 2    611199   6f3508        30Г2    114.3             7.0          Л
#
#    1 зона по ВТР закалка  2 зона по ВТР закалка  3 зона по ВТР закалка  \
# 0             877.805631             870.359609             898.801248
# 1             890.605514             879.244478             875.990538
# 2             867.256838             879.153898             902.585477
#
#    шаг балок закалочная печь, сек  \
# 0                       28.000000
# 1                       26.000001
# 2                       26.125000
#
#    Скорость прохождения трубы через спрейер, м/с  t˚ C трубы после спреера  \
# 0                                       0.252000                      37.5
# 1                                       0.313636                      42.5
# 2                                       0.228409                      42.5
#
#    1 зона ВТР и уставка отпуск  2 зона ВТР и уставка отпуск  \
# 0                   566.671570                   606.754592
# 1                   525.823426                   739.649909
# 2                   631.658749                   609.264699
#
#    3 зона ВТР и уставка отпуск  4 зона ВТР и уставка отпуск  \
# 0                   558.110961                   610.813662
# 1                   480.951811                   954.409577
# 2                   591.953238                   460.709299
#
#    5 зона ВТР и уставка отпуск  шаг балок отпускная печь, сек     C    Mn  \
# 0                   469.463957                      28.000005  0.14  0.48
# 1                   248.134526                      26.000000  0.29  1.29
# 2                   635.946413                      26.017032  0.28  1.38
#
#      Si      P      S    Cr    Ni    Cu     Al      V      Ti       Nb     Mo  \
# 0  0.24  0.007  0.003  0.53  0.05  0.10  0.033  0.053  0.0017  0.00355  0.007
# 1  0.23  0.012  0.008  0.06  0.05  0.08  0.030  0.003  0.0040  0.00553  0.005
# 2  0.25  0.007  0.006  0.09  0.12  0.19  0.030  0.003  0.0100  0.00200  0.010
#
#          N        B    C-coef  Параметр закалка  Параметр отпуск  \
# 0  0.00800  0.00094  0.348000        880.600619        16.126048
# 1  0.00892  0.00050  0.527267        856.775631        16.360236
# 2  0.00800  0.00050  0.551267        882.594193        16.394210
#
#    Параметр отпуск новый V  Величина зерна  Тип предела текучести (1186)  \
# 0                11.274847       15.388243                           0.2
# 1                10.082887       18.917484                           0.2
# 2                 9.921411       15.102891                           0.2
#
#   Дата термообработки       ICD  Текучесть середина  Прочность середина  \
# 0          2014-12-13  0.579200               55.00                75.0
# 1          2013-12-22  1.198637               65.00                85.0
# 2          2016-11-12  1.450899               77.35                92.3
#
#    длина трубы  pred Текучесть  pred Прочность
# 0     5.040000       50.559345       65.183112
# 1    13.800000       65.782507       81.452790
# 2    10.107109       75.952245       91.767781

# %%
output_df.to_excel('DATA/Optimizer/optimizer.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-56-198d9e07df8f> in <module>()
# ----> 1 output_df.to_excel('DATA/Optimizer/optimizer.xlsx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     652                            freeze_panes=freeze_panes)
#     653         if need_save:
# --> 654             writer.save()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py in save(self)
#    1730         """
#    1731
# -> 1732         return self.book.close()
#    1733
#    1734     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     309         if not self.fileclosed:
#     310             self.fileclosed = 1
# --> 311             self._store_workbook()
#     312
#     313     def set_size(self, width, height):
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     638
#     639         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 640                             allowZip64=self.allow_zip64)
#     641
#     642         # Add XML sub-files to the Zip file with their Excel filename.
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'DATA/Optimizer/optimizer.xlsx'
