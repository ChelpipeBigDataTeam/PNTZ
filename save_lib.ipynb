# %%
import os
from datetime import datetime
import json
import pickle
import theano
import keras
'''

ЗАПИСЬ МОДЕЛИ случайного леса В ФАЙЛ

'''
def save_RF_model(rfc):
    # Создаем папку для сохранения моделей, если ее еще нет
    model_directory = os.getcwd()+'/MODELS_RF'
    if not os.path.exists(model_directory):
        os.makedirs(model_directory)   


    # __________________________________________________________________________________
    # Создаем папку для конкретной модели (будет названа текущей датой и временем)
    now = datetime.now()
    time = "%d_%ddate %d_%d_%d_%dtime" % (now.day, now.month, now.hour, now.minute, 
                                          now.second, now.microsecond/100000)
    dir_name = model_directory+'/'+time
    os.mkdir(dir_name)


    # ___________________________________________________________________________
    #Сохраняем список параметров по которым строилась модель
    json.dump((ls_need_col), open(dir_name+'/'+'ls_need_col', "w"))
    ls_need_col_df = pd.DataFrame(data = {'feature':ls_need_col})


    '''Минутка наркомании для расширения колонки можно сильно не запариваться что здесь происходит'''
    file_name = dir_name+'/'+'model_'+target+'_feature_list.xlsx'
    writer = pd.ExcelWriter(file_name, engine='xlsxwriter')
    ls_need_col_df.to_excel(writer)
    sh = writer.sheets['Sheet1']
    sh.set_column(1, 1,80)
    writer.close()

    # На всякий случай пример как читать из файла потом, чтобы долго не искать
    # ls = json.load(open(dir_name+'/'+'ls_need_col', "r"))
    # ls

    # ___________________________________________________________________________
    #Сохраняем саму модель
    # Для сохранения лесов
    pickle.dump(rfc, open(dir_name+'/'+'RF_model_'+target+'.sav', 'wb'))

    # На всякий случай пример как читать из файла потом, чтобы долго не искать
    # tree_grid2 = pickle.load(open('model_текучесть 0.45r 570.sav', 'rb'))

    # ___________________________________________________________________________
    #Сохраняем score модели
    score_df.to_excel(dir_name+'/'+'RF_model_'+target+'_score.xlsx')

    print('Модель сохранена')

    
'''

ЗАПИСЬ МОДЕЛИ kerasNN В ФАЙЛ

'''
# Создаем папку для сохранения моделей, если ее еще нет
def save_NN_model(model):
    model_directory = os.getcwd()+'/MODELS_kerasNN'
    if not os.path.exists(model_directory):
        os.makedirs(model_directory)   


    # __________________________________________________________________________________
    # Создаем папку для конкретной модели (будет названа текущей датой и временем)
    now = datetime.now()
    time = "%d_%ddate %d_%d_%d_%dtime" % (now.day, now.month, now.hour, now.minute, 
                                          now.second, now.microsecond/100000)
    dir_name = model_directory+'/'+time
    os.mkdir(dir_name)


    # ___________________________________________________________________________
    #Сохраняем список параметров по которым строилась модель
    json.dump((ls_need_col), open(dir_name+'/'+'ls_need_col', "w"))
    ls_need_col_df = pd.DataFrame(data = {'feature':ls_need_col})


    '''Минутка наркомании для расширения колонки можно сильно не запариваться что здесь происходит'''
    file_name = dir_name+'/'+'model_'+target+'_feature_list.xlsx'
    writer = pd.ExcelWriter(file_name, engine='xlsxwriter')
    ls_need_col_df.to_excel(writer)
    sh = writer.sheets['Sheet1']
    sh.set_column(1, 1,80)
    writer.close()

    # На всякий случай пример как читать из файла потом, чтобы долго не искать
    # ls = json.load(open(dir_name+'/'+'ls_need_col', "r"))
    # ls

    # ___________________________________________________________________________
    #Сохраняем саму модель
    # Для сохранения лесов
#     pickle.dump(rfc, open(dir_name+'/'+'model_'+target+'.sav', 'wb'))
    model.save(dir_name+'/'+'kerasNN_model_'+target+'.h5')
    # На всякий случай пример как читать из файла потом, чтобы долго не искать
    # tree_grid2 = pickle.load(open('model_текучесть 0.45r 570.sav', 'rb'))

    # ___________________________________________________________________________
    #Сохраняем score модели
    score_df.to_excel(dir_name+'/'+'model_'+target+'_score.xlsx')

    print('Модель сохранена')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Repo\Anaconda2\envs\myenv\lib\configparser.py in _unify_values(self, section, vars)
#    1137         try:
# -> 1138             sectiondict = self._sections[section]
#    1139         except KeyError:
#
# KeyError: 'blas'
#
# During handling of the above exception, another exception occurred:
#
# NoSectionError                            Traceback (most recent call last)
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\configparser.py in fetch_val_for_key(key, delete_key)
#     167         try:
# --> 168             return theano_cfg.get(section, option)
#     169         except ConfigParser.InterpolationError:
#
# D:\Repo\Anaconda2\envs\myenv\lib\configparser.py in get(self, section, option, raw, vars, fallback)
#     780         try:
# --> 781             d = self._unify_values(section, vars)
#     782         except NoSectionError:
#
# D:\Repo\Anaconda2\envs\myenv\lib\configparser.py in _unify_values(self, section, vars)
#    1140             if section != self.default_section:
# -> 1141                 raise NoSectionError(section)
#    1142         # Update with the entry specific variables
#
# NoSectionError: No section: 'blas'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\configparser.py in __get__(self, cls, type_, delete_key)
#     327                 val_str = fetch_val_for_key(self.fullname,
# --> 328                                             delete_key=delete_key)
#     329                 self.is_default = False
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\configparser.py in fetch_val_for_key(key, delete_key)
#     171     except (ConfigParser.NoOptionError, ConfigParser.NoSectionError):
# --> 172         raise KeyError(key)
#     173
#
# KeyError: 'blas.ldflags'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-1f6be0a42e33> in <module>()
#       3 import json
#       4 import pickle
# ----> 5 import theano
#       6 import keras
#       7 '''
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\__init__.py in <module>()
#     122 from theano.printing import pprint, pp
#     123
# --> 124 from theano.scan_module import (scan, map, reduce, foldl, foldr, clone,
#     125                                 scan_checkpoints)
#     126
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\scan_module\__init__.py in <module>()
#      39 __contact__ = "Razvan Pascanu <r.pascanu@gmail>"
#      40
# ---> 41 from theano.scan_module import scan_opt
#      42 from theano.scan_module.scan import scan
#      43 from theano.scan_module.scan_checkpoints import scan_checkpoints
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\scan_module\scan_opt.py in <module>()
#      58
#      59 import theano
# ---> 60 from theano import tensor, scalar
#      61 from theano.tensor import opt, get_scalar_constant_value, Alloc, AllocEmpty
#      62 from theano import gof
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\tensor\__init__.py in <module>()
#      15 from theano.tensor import opt
#      16 from theano.tensor import opt_uncanonicalize
# ---> 17 from theano.tensor import blas
#      18 from theano.tensor import blas_scipy
#      19 from theano.tensor import blas_c
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\tensor\blas.py in <module>()
#     153 from theano.scalar import bool as bool_t
#     154 from theano.tensor import basic as T
# --> 155 from theano.tensor.blas_headers import blas_header_text
#     156 from theano.tensor.blas_headers import blas_header_version
#     157 from theano.tensor.opt import in2out, local_dimshuffle_lift
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\tensor\blas_headers.py in <module>()
#     985
#     986
# --> 987 if not config.blas.ldflags:
#     988     _logger.warning('Using NumPy C-API based implementation for BLAS functions.')
#     989
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\configparser.py in __get__(self, cls, type_, delete_key)
#     330             except KeyError:
#     331                 if callable(self.default):
# --> 332                     val_str = self.default()
#     333                 else:
#     334                     val_str = self.default
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\configdefaults.py in default_blas_ldflags()
#    1428         if res:
#    1429             if 'mkl' in res:
# -> 1430                 check_mkl_openmp()
#    1431             return res
#    1432
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\theano\configdefaults.py in check_mkl_openmp()
#    1250         import mkl
#    1251         if '2018' in mkl.get_version_string():
# -> 1252             raise RuntimeError('To use MKL 2018 with Theano you MUST set "MKL_THREADING_LAYER=GNU" in your environement.')
#    1253     except ImportError:
#    1254         raise RuntimeError("""
#
# RuntimeError: To use MKL 2018 with Theano you MUST set "MKL_THREADING_LAYER=GNU" in your environement.
