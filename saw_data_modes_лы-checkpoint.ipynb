# %%
import pandas as pd
import numpy as np
import re
import os
import import_ipynb
from modes_prepare_lib_лы import get_modes_dataframe
from datetime import datetime
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000

# %%
df_modes, df_valid = get_modes_dataframe()
# Out:
# 129559
# (129086, 38)
# 8989
# (8958, 24)

# %%
df = pd.read_csv('DATA/prepared/prepared_to_saw_gp.csv')
# Out:
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (1,3,4,5,6,7,9,10,11,14,16,17,18,19,20,21,24,25,27,28,30,32,33,34,35,36,38,39,40,41,42,44,45,46,47,49,51,53,55,56,57,58,59,60,61,63,64,65,69,70,71,72,73,76,77,78,80,81,82,83,84,85,86,87,88,90,92,93,94,97,100,101,102,103,106,107,108,109,111,113,114,116,117,119,121,123,128,129,130,133,134,135,138,139,140,141,142,143,144,146,147,150,151,152,153,155,156,160,162,166,167,168,169,170,174,176,177,179,181,182,184,186,187,189,190,191,193,194,195,196,197,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_valid = pd.read_excel('DATA/prepared/prepared_hard_valid.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-3d0a23be5045> in <module>()
# ----> 1 df_valid = pd.read_excel('DATA/prepared/prepared_hard_valid.xlsx')
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     236         convert_float=convert_float, skip_footer=skip_footer,
#     237         converters=converters, dtype=dtype, true_values=true_values,
# --> 238         false_values=false_values, squeeze=squeeze, **kwds)
#     239
#     240
#
# D:\Repo\Anaconda2\envs\myenv\lib\site-packages\pandas\io\excel.py in _parse_excel(self, sheetname, header, skiprows, names, skip_footer, index_col, usecols, parse_dates, date_parser, na_values, thousands, convert_float, true_values, false_values, verbose, dtype, squeeze, **kwds)
#     480
#     481                     if usecols is None or should_parse[j]:
# --> 482                         row.append(_parse_cell(value, typ))
#     483                 data.append(row)
#     484
#
# KeyboardInterrupt:

# %%
df_modes.shape, df_valid.shape
# Out:
# ((24503, 201), (1728, 200))

# %%
# df_valid.columns, df_modes.columns

# %%
# df_valid['масса\nтн'] = df_valid['масса\nтн.1']

# %%
def change_to17(x):
    if x.year>2018:
        try:
            tmp=x
            tmp = tmp.replace(year=2017, month=x.month, day=x.day)
            return tmp
        except:
            tmp = tmp.replace(year=2017, month=x.month, day=28)
            return tmp
    else:
        return x

def union_modes():
    global df_modes
    global df_valid
    result=list(set(df_modes.columns) & set(df_valid.columns))
    df_modes = df_modes[result]
    df_modes['Дата термообработки'].describe()
    df_valid = df_valid[result]
    
    df = pd.concat([df_modes, df_valid])
    df.reset_index(drop=True, inplace=True)
    return df

df = union_modes()

# %%
df['Дата термообработки'] = df['Дата термообработки'].apply(lambda x: str(x))
df['Дата термообработки'] = df['Дата термообработки'].apply(lambda x: x.replace('-', '.'))
df['Дата термообработки'] = df['Дата термообработки'].apply(lambda x: x.replace(' 00:00:00', ''))

# %%
df['Дата термообработки'].value_counts()
# Out:
# 04.07.2015    49
# 04.05.2014    44
# 04.03.2018    36
# 02.05.2016    35
# 26.04.2017    34
# 30.05.2015    34
# 13.10.2013    33
# 22.10.2016    33
# 03.03.2015    33
# 29.07.2017    32
# 10.02.2013    32
# 04.11.2016    30
# 10.04.2013    29
# 27.01.2018    28
# 01.12.2015    28
# 07.01.2016    27
# 18.02.2018    27
# 11.04.2015    27
# 04.01.2013    27
# 09.06.2015    27
# 01.05.2016    27
# 11.08.2017    27
# 04.06.2012    27
# 13.11.2015    27
# 11.03.2012    27
# 08.09.2013    27
# 24.08.2016    27
# 25.01.2012    26
# 24.01.2018    26
# 14.11.2015    26
# 22.08.2017    26
# 14.08.2012    26
# 20.07.2017    26
# 28.07.2014    26
# 25.07.2015    26
# 17.01.2018    26
# 21.05.2017    25
# 02.09.2017    25
# 29.05.2016    25
# 29.03.2013    25
# 04.04.2018    25
# 28.08.2013    25
# 28.05.2016    25
# 25.09.2015    25
# 29.05.2017    25
# 01.04.2015    25
# 17.05.2017    25
# 03.12.2015    25
# 12.08.2017    25
# 01.08.2017    25
# 13.08.2017    25
# 13.09.2017    25
# 10.01.2015    25
# 23.08.2014    25
# 30.07.2017    25
# 20.02.2013    24
# 11.01.2017    24
# 24.08.2014    24
# 04.04.2016    24
# 07.09.2015    24
# 23.11.2016    24
# 12.06.2016    24
# 04.01.2014    24
# 14.05.2017    24
# 05.06.2014    24
# 03.04.2016    24
# 14.08.2015    24
# 09.05.2012    24
# 22.02.2018    24
# 14.02.2014    24
# 29.09.2013    24
# 27.07.2017    24
# 21.02.2017    24
# 01.05.2014    24
# 27.12.2016    23
# 06.04.2014    23
# 11.01.2018    23
# 05.08.2013    23
# 29.08.2017    23
# 12.09.2016    23
# 27.09.2015    23
# 20.04.2015    23
# 08.05.2017    23
# 21.08.2013    23
# 26.04.2014    23
# 03.08.2014    23
# 20.06.2014    23
# 23.02.2018    23
# 21.02.2015    23
# 17.10.2015    23
# 30.03.2013    23
# 20.04.2019    23
# 2017.10.13    23
# 25.01.2018    23
# 26.01.2018    23
# 22.07.2017    23
# 06.06.2014    23
# 30.04.2014    23
# 25.04.2016    23
# 01.08.2015    23
# 02.04.2017    23
# 27.04.2015    22
# 16.07.2014    22
# 31.05.2017    22
# 27.01.2013    22
# 09.01.2012    22
# 23.08.2013    22
# 14.06.2015    22
# 10.07.2017    22
# 08.07.2017    22
# 17.04.2016    22
# 23.02.2015    22
# 19.12.2017    22
# 29.04.2014    22
# 07.12.2013    22
# 24.03.2013    22
# 29.04.2017    22
# 22.04.2013    22
# 02.05.2014    22
# 12.04.2013    22
# 09.08.2016    22
# 03.07.2016    22
# 22.11.2015    22
# 29.07.2012    22
# 28.02.2017    22
# 06.07.2015     1
# 10.09.2013     1
# 19.01.2014     1
# 30.04.2017     1
# 25.04.2013     1
# 11.12.2012     1
# 2017.10.02     1
# 28.12.2015     1
# 06.01.2013     1
# 07.11.2014     1
# 2017.10.04     1
# 07.08.2015     1
# 04.02.2016     1
# 28.02.2016     1
# 30.01.2012     1
# 27.11.2015     1
# 20.06.2013     1
# 11.04.2014     1
# 18.01.2015     1
# 04.01.2012     1
# 19.05.2013     1
# 06.03.2013     1
# 03.03.2012     1
# 22.07.2012     1
# 06.10.2012     1
# 24.01.2015     1
# 10.09.2015     1
# 27.02.2015     1
# 15.04.2013     1
# 12.05.2015     1
# 17.03.2012     1
# 24.01.2017     1
# 07.03.2015     1
# 03.01.2016     1
# 01.07.2014     1
# 18.10.2016     1
# 2017.11.20     1
# 11.09.2016     1
# 19.01.2017     1
# 24.07.2012     1
# 21.09.2012     1
# 2017.11.13     1
# 17.04.2015     1
# 17.03.2013     1
# 19.12.2013     1
# Name: Дата термообработки, Length: 2023, dtype: int64

# %%
timestamp_df = df[df['Дата термообработки'].apply(type)==pd._libs.tslib.Timestamp]
last_df = df[df['Дата термообработки'].apply(type)!=pd._libs.tslib.Timestamp]
tmp = []
for x in last_df['Дата термообработки']:
    try:
        tmp.append(datetime.strptime(x, "%d.%m.%Y"))
    except ValueError:
        tmp.append(datetime.strptime(x, "%Y.%m.%d"))
last_df['Дата термообработки'] = tmp
timestamp_df['Дата термообработки'] = timestamp_df['Дата термообработки'].apply(
    pd._libs.tslib.Timestamp.to_pydatetime)

# %%
last_df['Дата термообработки'].value_counts()
# Out:
# 2015-07-04    49
# 2014-05-04    44
# 2018-03-04    36
# 2016-05-02    35
# 2015-05-30    34
# 2017-04-26    34
# 2015-03-03    33
# 2016-10-22    33
# 2013-10-13    33
# 2013-02-10    32
# 2017-07-29    32
# 2016-11-04    30
# 2013-04-10    29
# 2018-01-27    28
# 2015-12-01    28
# 2016-01-07    27
# 2012-06-04    27
# 2015-06-09    27
# 2013-01-04    27
# 2018-02-18    27
# 2017-08-11    27
# 2016-05-01    27
# 2015-11-13    27
# 2016-08-24    27
# 2012-03-11    27
# 2013-09-08    27
# 2015-04-11    27
# 2014-07-28    26
# 2015-07-25    26
# 2018-01-24    26
# 2017-07-20    26
# 2012-01-25    26
# 2017-08-22    26
# 2015-11-14    26
# 2012-08-14    26
# 2018-01-17    26
# 2017-08-13    25
# 2017-05-21    25
# 2017-05-29    25
# 2017-05-17    25
# 2016-05-29    25
# 2015-09-25    25
# 2017-09-13    25
# 2017-08-12    25
# 2015-01-10    25
# 2017-08-01    25
# 2016-05-28    25
# 2015-12-03    25
# 2018-04-04    25
# 2013-03-29    25
# 2017-07-30    25
# 2014-08-23    25
# 2013-08-28    25
# 2017-09-02    25
# 2015-04-01    25
# 2014-06-05    24
# 2016-11-23    24
# 2017-07-27    24
# 2014-02-14    24
# 2016-06-12    24
# 2016-04-03    24
# 2015-09-07    24
# 2014-08-24    24
# 2018-02-22    24
# 2016-04-04    24
# 2015-07-31     2
# 2017-11-06     2
# 2012-12-12     2
# 2016-02-20     2
# 2014-12-23     2
# 2012-02-11     2
# 2013-04-07     2
# 2017-04-14     2
# 2017-11-14     2
# 2014-11-27     2
# 2012-02-07     2
# 2016-06-16     2
# 2013-05-26     2
# 2015-07-21     2
# 2016-01-04     2
# 2017-04-06     2
# 2017-07-06     2
# 2015-01-12     2
# 2014-06-02     2
# 2012-02-08     2
# 2016-10-11     2
# 2017-04-24     2
# 2016-08-22     2
# 2015-08-21     2
# 2013-04-21     2
# 2015-03-24     2
# 2014-05-23     2
# 2013-04-03     2
# 2013-03-21     2
# 2016-12-08     2
# 2016-10-31     1
# 2016-01-02     1
# 2015-04-17     1
# 2015-11-27     1
# 2017-01-19     1
# 2014-07-01     1
# 2013-05-25     1
# 2017-10-20     1
# 2016-10-18     1
# 2015-01-17     1
# 2016-02-28     1
# 2012-05-24     1
# 2013-03-06     1
# 2016-02-04     1
# 2014-11-07     1
# 2013-03-17     1
# 2015-01-18     1
# 2012-07-22     1
# 2012-01-02     1
# 2015-02-16     1
# 2015-08-07     1
# 2013-01-06     1
# 2012-10-28     1
# 2014-11-11     1
# 2017-12-28     1
# 2017-01-24     1
# 2014-06-15     1
# 2012-05-08     1
# 2012-10-06     1
# 2016-09-11     1
# 2015-07-19     1
# 2016-01-03     1
# 2015-01-24     1
# 2015-04-12     1
# 2016-05-08     1
# 2017-10-04     1
# 2015-12-19     1
# 2016-02-03     1
# 2014-12-11     1
# 2015-12-28     1
# 2013-05-19     1
# 2015-09-10     1
# 2012-07-24     1
# 2014-04-11     1
# 2017-04-30     1
# 2015-07-06     1
# 2012-06-18     1
# 2012-03-04     1
# 2012-01-07     1
# 2013-04-25     1
# 2015-03-01     1
# 2016-10-10     1
# 2014-01-19     1
# 2012-01-30     1
# 2012-03-17     1
# 2012-12-11     1
# 2017-11-09     1
# 2013-06-20     1
# 2013-09-10     1
# 2017-11-13     1
# 2017-11-18     1
# 2015-03-07     1
# 2013-04-28     1
# 2012-01-04     1
# 2015-02-27     1
# 2012-09-21     1
# 2015-05-12     1
# 2017-11-20     1
# 2012-12-04     1
# 2013-04-15     1
# 2015-05-18     1
# 2017-10-02     1
# 2014-05-07     1
# 2012-03-03     1
# 2013-12-19     1
# Name: Дата термообработки, Length: 2023, dtype: int64

# %%
last_df['Дата термообработки'] = last_df['Дата термообработки'].apply(change_to17)
print(last_df[last_df['Дата термообработки'].apply(lambda x:x.year)>2018].shape)
last_df.shape
df = pd.concat([last_df, timestamp_df])
df.reset_index(drop=True, inplace=True)
# Out:
# (0, 200)

# %%
# pd.DataFrame(df['Дата термообработки'].value_counts().sort_index().index).to_excel('1.xlsx')

# %%
df.shape
# Out:
# (24503, 200)

# %%
def isDigit(x):
    try:
        float(x)
        return True
    except ValueError:
        return False

# %%
df = df[df['диаметр'].apply(isDigit)]
df = df[df['толщина стенки'].apply(isDigit)]
df.shape
# Out:
# (24503, 200)

# %%
# df.to_excel('for_top_typesizes.xlsx')

# %%
# df['диаметр'].value_counts().sort_index()

# %%
df.columns
# Out:
# Index(['излом', 'диаметр', 'Пред.текуч. МПа.8', 'свет.полоса',
#        'пред текуч.20 Н/мм2.14', 'вр.сопр t=20Н/мм2.6', 'вр.сопр t=20Н/мм2.5',
#        '3 зона ВТР и уставка отпуск', 'Врем.сопротив. МПА.1',
#        'пред текуч.20 Н/мм2.5',
#        ...
#        'пред текуч.20 Н/мм2.13', 'Sn', 'Сплющ..1', 'Сэ', 'нитриды.10',
#        'вр.сопр t=20Н/мм2.3', 'ликв.пол.и трещ', 'Поставщик',
#        '4 зона ВТР и уставка отпуск', 'пред текуч.20 Н/мм2.12'],
#       dtype='object', length=200)

# %%
def conv2float(x):
    try:
        return float(x)
    except:
        return None

# %%
for x in df['шаг балок отпускная печь, сек']:
    try:
        x = float(x)
    except:
        print(x)

# %%
df['диаметр'] = df['диаметр'].astype(float)
df['толщина стенки'] = df['толщина стенки'].astype(float)
df['шаг балок закалочная печь, сек'] = df['шаг балок закалочная печь, сек'].apply(conv2float)
df['шаг балок отпускная печь, сек'] = df['шаг балок отпускная печь, сек'].apply(conv2float)

# %%
df.shape
# Out:
# (24503, 200)

# %%
df.to_csv('prepared_to_saw_gp.csv')

# %%
df.to_csv('D:\Repo\PycharmProjects\RELEASE\PNTZ_64\DATA\prepared_to_saw_gp.csv')
df.to_csv('DATA\prepared\prepared_to_saw_gp.csv')

# %%
def find_mark_typesize(mark, d, s):
    answ = df.copy()
    if mark!=None:
        answ = answ[answ['марка стали']==mark]
#     print(answ.shape)
    if d!=None:
        answ = answ[answ['диаметр']==d]
#     print(answ.shape)
    if s!=None:
        answ = answ[answ['толщина стенки']==s]
#     print(answ.shape)
    return answ

# %%
def find_mark_typesize_2018(mark, d, s):
    answ = df[df['Дата термообработки'].apply(lambda x: x.year == 2018)].copy()
    if mark!=None:
        answ = answ[answ['марка стали']==mark]
#     print(answ.shape)
    if d!=None:
        answ = answ[answ['диаметр']==d]
#     print(answ.shape)
    if s!=None:
        answ = answ[answ['толщина стенки']==s]
#     print(answ.shape)
    return answ

# %%
# список 15 самых массовых заказов типоразмеров по версии 2017г
top_typesizes = [
    ['30Г2',73.02,5.51],
    ['30Г2',177.8,9.2],
    ['30Г2',73,5.5],
    ['18ХМФБ',73.02,5.51],
    ['30Г2-8',73.02,5.51],
    ['30Г2',88.9,6.5],
    ['37Г2Ф',168.28,8.94],
    ['30Г2',88.9,6.45],
    ['37Г2Ф',177.8,9.2],
    ['30Г2',168.28,8.94],
    ['18ХМФБ',73,5.5],
    ['37Г2Ф',88.9,12.2],
    ['38Г2С',73,5.5],
    ['30Г2-8',73,5.5],

]

# %%
answ1 = find_mark_typesize('18ХМФБ',73.02,5.51)

# %%
answ1[answ1['Дата термообработки'] == answ1['Дата термообработки'].max()][:3]
# Out:
#       2 зона по ВТР закалка 3 зона по ВТР закалка НД (гост, ту)  \
# 16514                   870                   880         ТУ 21
# 35737                   870                   880         ТУ 21
# 35738                   870                   880         ТУ 21
#
#       время выдержки в закалочной ванне, сек.  t˚ C трубы после спреера  \
# 16514                                     NaN                      70.0
# 35737                                                              70.0
# 35738                                                              70.0
#
#       марка стали  диаметр 3 зона ВТР и уставка отпуск  \
# 16514      18ХМФБ    73.02                         659
# 35737      18ХМФБ    73.02                         659
# 35738      18ХМФБ    73.02                         659
#
#        шаг балок закалочная печь, сек  t˚ C трубы после ванны  \
# 16514                            27.0                     NaN
# 35737                            27.0                     NaN
# 35738                            27.0                     NaN
#
#       1 зона по ВТР закалка  шаг балок отпускная печь, сек  \
# 16514                   870                           27.0
# 35737                   870                           27.0
# 35738                   870                           27.0
#
#       1 зона ВТР и уставка отпуск 2 зона ВТР и уставка отпуск  \
# 16514                         670                         670
# 35737                         670                         670
# 35738                         670                         670
#
#       5 зона ВТР и уставка отпуск № партии  \
# 16514                         642   804140
# 35737                         642   804138
# 35738                         642   804138
#
#       Скорость прохождения трубы через спрейер, м/с  \
# 16514                                           0.7
# 35737                                           0.7
# 35738                                           0.7
#
#       4 зона ВТР и уставка отпуск  масса\nтн Дата термообработки № плавки  \
# 16514                         659       3.60          2018-04-11   8f1869
# 35737                         659       4.79          2018-04-11   8f1869
# 35738                         659       4.77          2018-04-11   8f1869
#
#        толщина стенки
# 16514            5.51
# 35737            5.51
# 35738            5.51

# %%
top = pd.read_excel('jule_groups_8.xlsx')

# %%
top=top.sort_values('масса\nтн', ascending=False)

# %%
top_ls = top.copy()

# %%
# поиск топовых типоразмеров в файлах за 2018г для валидации
for i in range(0,len(top_ls)):
    print(find_mark_typesize_2018(top_ls.iloc[i,:][0], top_ls.iloc[i,:][1], top_ls.iloc[i,:][2]).shape, '\n', top_ls.iloc[i, :])
# Out:
# (416, 23)
#  марка стали          30Г2
# диаметр             73.02
# толщина стенки       5.51
# масса\nтн         11970.1
# Name: 0, dtype: object
# (349, 23)
#  марка стали          30Г2
# диаметр             177.8
# толщина стенки        9.2
# масса\nтн         10077.9
# Name: 1, dtype: object
# (373, 23)
#  марка стали          30Г2
# диаметр                73
# толщина стенки        5.5
# масса\nтн         7731.34
# Name: 2, dtype: object
# (21, 23)
#  марка стали        18ХМФБ
# диаметр             73.02
# толщина стенки       5.51
# масса\nтн         7616.75
# Name: 3, dtype: object
# (122, 23)
#  марка стали        30Г2-8
# диаметр             73.02
# толщина стенки       5.51
# масса\nтн         4899.12
# Name: 4, dtype: object
# (256, 23)
#  марка стали          30Г2
# диаметр              88.9
# толщина стенки        6.5
# масса\nтн         3185.25
# Name: 5, dtype: object
# (0, 23)
#  марка стали         37Г2Ф
# диаметр            168.28
# толщина стенки       8.94
# масса\nтн         2975.13
# Name: 6, dtype: object
# (65, 23)
#  марка стали          30Г2
# диаметр              88.9
# толщина стенки       6.45
# масса\nтн         2074.51
# Name: 7, dtype: object
# (393, 23)
#  марка стали         37Г2Ф
# диаметр             177.8
# толщина стенки        9.2
# масса\nтн         2054.03
# Name: 8, dtype: object
# (63, 23)
#  марка стали          30Г2
# диаметр            168.28
# толщина стенки       8.94
# масса\nтн         2029.17
# Name: 9, dtype: object
# (0, 23)
#  марка стали        18ХМФБ
# диаметр                73
# толщина стенки        5.5
# масса\nтн         1898.62
# Name: 10, dtype: object
# (67, 23)
#  марка стали         37Г2Ф
# диаметр              88.9
# толщина стенки       12.2
# масса\nтн         1464.68
# Name: 11, dtype: object
# (4, 23)
#  марка стали         38Г2С
# диаметр                73
# толщина стенки        5.5
# масса\nтн         1328.27
# Name: 12, dtype: object
# (61, 23)
#  марка стали        30Г2-8
# диаметр                73
# толщина стенки        5.5
# масса\nтн         1046.28
# Name: 13, dtype: object
# (0, 23)
#  марка стали        37Г2Ф
# диаметр               73
# толщина стенки       5.5
# масса\nтн         941.65
# Name: 14, dtype: object
# (0, 23)
#  марка стали        13ХФА
# диаметр               89
# толщина стенки        10
# масса\nтн         912.33
# Name: 15, dtype: object
# (143, 23)
#  марка стали       38Г2С-9
# диаметр                73
# толщина стенки        5.5
# масса\nтн          829.25
# Name: 16, dtype: object
# (10, 23)
#  марка стали       30ХГМА
# диаметр            194.5
# толщина стенки      19.7
# масса\nтн         783.27
# Name: 17, dtype: object
# (0, 23)
#  марка стали       37Г2Ф
# диаметр            88.9
# толщина стенки       13
# масса\nтн         782.3
# Name: 18, dtype: object
# (0, 23)
#  марка стали        13ХФА
# диаметр              219
# толщина стенки        18
# масса\nтн         726.96
# Name: 19, dtype: object
# (0, 23)
#  марка стали       30ХГМА-4
# диаметр               88.9
# толщина стенки        7.34
# масса\nтн           715.97
# Name: 20, dtype: object
# (45, 23)
#  марка стали        37Г2Ф
# диаметр            194.5
# толщина стенки      14.5
# масса\nтн         715.34
# Name: 21, dtype: object
# (0, 23)
#  марка стали        13ХФА
# диаметр              219
# толщина стенки        14
# масса\nтн         636.57
# Name: 22, dtype: object
# (0, 23)
#  марка стали        37Г2Ф
# диаметр            93.17
# толщина стенки      12.5
# масса\nтн         627.48
# Name: 23, dtype: object
# (0, 23)
#  марка стали        38Г2С
# диаметр            73.02
# толщина стенки      5.51
# масса\nтн         619.52
# Name: 24, dtype: object
# (0, 23)
#  марка стали       18ХМФБ
# диаметр            177.8
# толщина стенки      9.19
# масса\nтн         616.53
# Name: 25, dtype: object
# (0, 23)
#  марка стали       30ХГМА
# диаметр             88.9
# толщина стенки      6.45
# масса\nтн         598.14
# Name: 26, dtype: object
# (0, 23)
#  марка стали       30ХГМА-4
# диаметр              194.5
# толщина стенки        19.7
# масса\nтн           526.18
# Name: 27, dtype: object
# (0, 23)
#  марка стали        37Г2Ф
# диаметр            114.3
# толщина стенки       6.4
# масса\nтн         504.53
# Name: 28, dtype: object
# (14, 23)
#  марка стали        37Г2Ф
# диаметр            73.02
# толщина стенки      10.5
# масса\nтн         483.97
# Name: 29, dtype: object

# %%
top_ls['диаметр'] = top_ls['диаметр'].astype(float)

# %%
top_ls.reset_index(inplace=True, drop=True)

# %%
df.shape
# Out:
# (24503, 201)

# %%
# якобы минимальные шаги топовых типоразмеров
for i in range(0,len(top_ls)):
    answ = find_close_sort(top_ls.iloc[i,:][1], top_ls.iloc[i,:][3], top_ls.iloc[i,:][2])
    answ  = answ[answ['шаг балок отпускная печь, сек'] >= 24]
    answ  = answ[answ['шаг балок закалочная печь, сек'] >= 24]   
    print(answ['шаг балок отпускная печь, сек'].min(), answ['шаг балок закалочная печь, сек'].min(), top_ls.iloc[i,:])
# Out:
# 24.0 24.0                                        0
# марка стали                       18ХМФБ
# толщина стенки                      5.51
# диаметр                            73.02
# шаг балок закалочная печь, сек        27
# шаг балок отпускная печь, сек         27
# масса\nтн.1                        81.35
# Name: 0, dtype: object
# 36.0 36.0                                        1
# марка стали                       18ХМФБ
# толщина стенки                       9.2
# диаметр                            177.8
# шаг балок закалочная печь, сек        36
# шаг балок отпускная печь, сек         36
# масса\nтн.1                       817.39
# Name: 1, dtype: object
# 24.0 24.0                                        2
# марка стали                         30Г2
# толщина стенки                       5.5
# диаметр                               73
# шаг балок закалочная печь, сек        24
# шаг балок отпускная печь, сек         24
# масса\nтн.1                       754.71
# Name: 2, dtype: object
# 36.0 36.0                                          6
# марка стали                       30ХГМА-4
# толщина стенки                        11.8
# диаметр                              93.17
# шаг балок закалочная печь, сек          36
# шаг балок отпускная печь, сек           36
# масса\nтн.1                          10.67
# Name: 3, dtype: object
# 42.0 55.0                                       7
# марка стали                        32ХА
# толщина стенки                       24
# диаметр                             198
# шаг балок закалочная печь, сек       45
# шаг балок отпускная печь, сек        45
# масса\nтн.1                       90.84
# Name: 4, dtype: object
# 34.0 34.0                                       8
# марка стали                       37Г2Ф
# толщина стенки                       11
# диаметр                            77.8
# шаг балок закалочная печь, сек       32
# шаг балок отпускная печь, сек        32
# масса\nтн.1                        7.32
# Name: 5, dtype: object
# 30.0 36.0                                       9
# марка стали                       37Г2Ф
# толщина стенки                     11.8
# диаметр                           93.17
# шаг балок закалочная печь, сек       32
# шаг балок отпускная печь, сек        30
# масса\nтн.1                       75.78
# Name: 6, dtype: object
# 30.0 32.0                                      11
# марка стали                       37Г2Ф
# толщина стенки                     12.2
# диаметр                            88.9
# шаг балок закалочная печь, сек       36
# шаг балок отпускная печь, сек        32
# масса\nтн.1                        4.43
# Name: 7, dtype: object
# 24.0 24.0                                      12
# марка стали                       37Г2Ф
# толщина стенки                      5.5
# диаметр                              73
# шаг балок закалочная печь, сек       24
# шаг балок отпускная печь, сек        24
# масса\nтн.1                       54.15
# Name: 8, dtype: object
# 30.0 30.0                                       13
# марка стали                        37Г2Ф
# толщина стенки                      8.94
# диаметр                           168.28
# шаг балок закалочная печь, сек        30
# шаг балок отпускная печь, сек         30
# масса\nтн.1                       445.65
# Name: 9, dtype: object
# nan nan                                       14
# марка стали                       37Г2Ф
# толщина стенки                      11.8
# диаметр                            93.17
# шаг балок закалочная печь, сек        36
# шаг балок отпускная печь, сек         36
# масса\nтн.1                        13.09
# Name: 10, dtype: object
# nan nan                                       15
# марка стали                       37Г2Ф
# толщина стенки                      12.5
# диаметр                              127
# шаг балок закалочная печь, сек        36
# шаг балок отпускная печь, сек         36
# масса\nтн.1                         5.89
# Name: 11, dtype: object
# 32.0 32.0                                        16
# марка стали                       37Г2Ф-2
# толщина стенки                       10.5
# диаметр                             73.02
# шаг балок закалочная печь, сек         32
# шаг балок отпускная печь, сек          32
# масса\nтн.1                         18.07
# Name: 12, dtype: object
# 24.0 24.0                                      17
# марка стали                       38Г2С
# толщина стенки                     11.8
# диаметр                           93.17
# шаг балок закалочная печь, сек       36
# шаг балок отпускная печь, сек        32
# масса\nтн.1                       39.59
# Name: 13, dtype: object
# 24.0 24.0                                      18
# марка стали                       38Г2С
# толщина стенки                      5.5
# диаметр                              73
# шаг балок закалочная печь, сек       24
# шаг балок отпускная печь, сек        24
# масса\nтн.1                        8.92
# Name: 14, dtype: object

# %%
answ = find_mark_typesize('13ХФА', 114, 6)
answ.shape
# Out:
# (602, 23)

# %%
# answ['марка стали'].value_counts()

# %%
answ['толщина стенки'].value_counts()
# Out:
# 6.0    602
# Name: толщина стенки, dtype: int64

# %%
answ.sort_values('Дата термообработки', ascending=False).head(1).to_excel('114x6 13hfa.xlsx')
answ.sort_values('Дата термообработки', ascending=False).head(1)
# Out:
#       2 зона ВТР и уставка отпуск шаг балок отпускная печь, сек  \
# 12638                         715                            27
#
#       Дата термообработки 3 зона по ВТР закалка  диаметр № плавки масса\nтн  \
# 12638          2017-09-03                   870    114.0     4460      3.88
#
#       НД (гост, ту) 1 зона по ВТР закалка 3 зона ВТР и уставка отпуск  \
# 12638         ТУ 15                   860                         701
#
#       № партии 1 зона ВТР и уставка отпуск  t˚ C трубы после ванны  \
# 12638   709046                         715                     NaN
#
#       марка стали  t˚ C трубы после спреера  толщина стенки  \
# 12638       13ХФА                      47.5             6.0
#
#       4 зона ВТР и уставка отпуск  \
# 12638                         701
#
#       Скорость прохождения трубы через спрейер, м/с  \
# 12638                                          0.47
#
#       5 зона ВТР и уставка отпуск время выдержки в закалочной ванне, сек.  \
# 12638                         686
#
#         № пакета 2 зона по ВТР закалка шаг балок закалочная печь, сек
# 12638  101674596                   860                             29

# %%
plan_may = pd.read_excel('D:\\Repo\\PycharmProjects\\gitPNTZ\\tmp_files\\план на май\\план_на_май_ПНТЗ.xlsx')
plan_may = plan_may[['Сортамент|Марка стали','Сортамент|Диам1', 'Сортамент|Стен1']]
plan_may.columns = [['марка стали', 'диаметр', 'толщина стенки']]
plan_may.drop_duplicates(inplace=True)
plan_may.reset_index(drop=True, inplace=True)

# %%
def close_value(df, row, value):
    s_close = df[row].value_counts().index[0]
    min_delta = np.abs(s_close-value)
    for s_ in df[row].value_counts().index:
        delta = np.abs(s_-value)
        if delta<min_delta:
            min_delta = delta
            s_close = s_
    return s_close

# %%
modes_old.to_excel('modes_old.xlsx')

# %%
answ = find_close_sort('37Г2Ф', 60, 5)
answ.sort_values('Дата термообработки', ascending=False).head(1)
# Out:
# (1, 26)
# 37Г2Ф 60 5
#        шаг балок закалочная печь, сек время начала т/о  \
# 132658                             24             2-55
#
#        шаг балок отпускная печь, сек НД (гост, ту)  \
# 132658                            24        633-80
#
#        Скорость прохождения трубы через спрейер, м/с t˚ C трубы после ванны  \
# 132658                                           0,7                    НЕТ
#
#          № пакета 3 зона по ВТР закалка     D/S 2 зона по ВТР закалка  \
# 132658  403379663                   860  60,3Х5                   850
#
#        3 зона ВТР и уставка отпуск 5 зона ВТР и уставка отпуск  \
# 132658                         673                         656
#
#        Дата термообработки 4 зона ВТР и уставка отпуск 1 зона по ВТР закалка  \
# 132658          2017-10-18                         673                   850
#
#        марка стали кол-во, шт. 1 зона ВТР и уставка отпуск  диаметр  \
# 132658       37Г2Ф          34                         685     60.3
#
#        время выдержки в закалочной ванне, сек.  плавка  \
# 132658                                     НЕТ  7F6803
#
#        2 зона ВТР и уставка отпуск  толщина стенки t˚ C трубы после спреера  \
# 132658                         685             5.0                    65-75
#
#        шаг балок закалочная/отпускная печи, сек № партии
# 132658                                    24/24   710294

# %%
def

# %%
def find_close_sort(mark, d, s):
    answ = df.copy()
    if answ[answ['марка стали']==d].shape[0]==0:
        mark = mark.split('-')[0]
    answ = answ[answ['марка стали']==mark]
    if answ[answ['диаметр']==d].shape[0]!=0:
        answ = answ[answ['диаметр']==d]
        s_close = close_value(answ, 'толщина стенки',s)
        answ = answ[answ['толщина стенки']==s_close]
    elif answ[answ['толщина стенки']==s].shape[0]!=0:
        answ = answ[answ['толщина стенки']==s]
        d_close = close_value(answ, 'диаметр',d)
#         print(answ.shape)
        answ = answ[answ['диаметр']==d_close]
    return answ

# %%
modes_old = pd.DataFrame()

for i in plan_may.index:
    mark = plan_may.iloc[i, 0]
    d = plan_may.iloc[i,1]
    s = plan_may.iloc[i,2]
    s = s.round(2)
#     print(mark, d, s)
    tmp = find_mark_typesize(mark, d, s)
    if tmp.shape[0]!=0:
        modes_old = pd.concat([modes_old, tmp.sort_values('Дата термообработки', ascending=False).head(1)])
    else:
        tmp = pd.DataFrame({
            '0_марка стали': [mark],
            '0_диаметр':[d],
            '0_толщина стенки':[s]})
        tmp_right = find_close_sort(mark, d, s)
        st = tmp_right.sort_values('Дата термообработки', ascending=False).head(1)
        st.reset_index(drop=True, inplace=True)
        tmp = pd.concat([tmp,st], axis=1)
        modes_old = pd.concat([modes_old, tmp])
#     print(mark, d, s)
# Out:
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)
# (1, 3) (1, 26)
# (1, 29)

# %%
modes_old.to_excel('modes_old.xlsx')

# %%
find_close_sort('13ХФА', 114, 6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-28a716eaa982> in <module>()
# ----> 1 find_close_sort('13ХФА', 114, 6)
#
# NameError: name 'find_close_sort' is not defined
